# %% [markdown]
# # 1-1_setup
#
# Want to test if your computer is properly set up for the course? Try running this code:

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_facecolor("#f5f0e6")
fig.patch.set_facecolor("#f5f0e6")
ax.text(
    0.5, 0.6,
    "Welcome to DIGHUM101!",
    ha="center",
    va="center",
    fontsize=36,
    fontweight="bold"
)

ax.text(
    0.5, 0.38,
    "Digital Humanities + Python",
    ha="center",
    va="center",
    fontsize=20
)

ax.axis("off")
plt.show()

# %% [markdown]
# If the code didn't run correctly or you're not sure, do not worry! We'll go over all the setup steps together in class.

# %% [markdown]
# ## Learning Objectives
#
# 1) Learn about Digital Humanities and D-Lab at Berkeley
# 2) Learn about syllabus, major assignments, and course structure
# 3) Learn about instructor, GSI, and classmates
# 4) Software installations
# 5) Downloading course materials
# 6) Navigating VS Code and Jupyter Notebooks
#
# ## Welcome to DIGHUM 101!
#
# This class is part of the [Digital Humanities at Berkeley Summer Program](https://summerdigitalhumanities.berkeley.edu/). Alongside DIGHUM 100: Theory and Methods in DH, it one of the required core courses.
#
# ### Why is Python in DH a required course?
#
# - Python is widely used in DH
# - Learning Python allows you to conduct a wide range of DH research and scholarship
# - Python is versatile. It continues to prove useful as new DH theories and methods develop in the field.
#
# ### What is Python?
#
# Python is a [programming language](https://en.wikipedia.org/wiki/Programming_language)-a formal set of rules, symbols, and syntax used by developers to create instructions that computers can understand and execute. [Python](https://en.wikipedia.org/wiki/Python_(programming_language)) is a high level, general-purpose, object-oriented programming language favored for its readability and versatility. In DH and most other contexts, Python is used to interact with [data.](https://en.wikipedia.org/wiki/Data) It allows you to compile, create, process, merge, compute, interpret, and visualize data.
#
# ## Syllabus
#
# The [README.md](https://github.com/dlab-berkeley/DIGHUM101-2026/blob/main/README.md) file in the course GitHub Repository serves as the public syllabus. Here are some parts worth highlighting:
#
# ### Course Learning Objectives
#
# The goal of this course is to teach you basic principles for conducting professional research in the Digital Humanities. You will learn how to program Python in Jupyter Notebooks to access, explore, visualize, and analyze data in humanities contexts. You are strongly encouraged to concurrently enroll in [DIGHUM 100 – Theory and Methods in the Digital Humanities](https://classes.berkeley.edu/index.php/content/2025-summer-dighum-100-001-lec-001) to complement this experience with a strong theoretical foundation. By the end of this course, you will learn:
#
# - A variety of Pythonic approaches to explore questions in the humanities;
# - How to understand data more holistically, its generative process - and lifecycle;
# - Strategies for organizing research projects based on your interests;
# - Methods for data acquisition and visualization, computational text analysis, and machine learning;
# - The importance of developing a critical lens in your field of study.
#
# ### Course Overview
#
# This course will meet four days a week on Zoom. Each class is divided into two types:
#
# - __Lecture days:__ The instructor will lecture on core concepts in Python and the digital humanities and provide coding walkthroughs in Jupyter notebooks. Most lecture days will also include coding exercises and time for questions and discussion.
# - __Project days:__ These days will be exclusively focused on your individual and group projects. They are structured work time with the instructor(s) available to answer questions or concerns.
#
# ### Assignments and Grading
#
# - Attendance and Participation: 10%
#
# - Individual Project
#
#     - Topic Statement: 10%
#     - Demonstration of Code: 20%
#     - Project Showcase: 10%
#
# - Group Project
#
#     - Topic Statement: 10%
#     - Short Paper: 20%
#     - Presentation: 10%
#
# - Final Video Reflection: 10%
#
# Grading is straight scale: A=90-100; B=80-89; C=70-79; D=60-69; F<60
#
# ### Assignment Descriptions
#
# #### Attendance
#
# This course is synchronous and attendance is required. Attendance will be tracked through Zoom sign-ins. Please be present during our Zoom meetings. Come prepared to listen, ask questions, make comments, and attempt coding exercises.
#
# Attendance makes up 10% of your overall grade.
#
# #### Individual Project
#
# The individual coding project is an opportunity to become more comfortable with Python. The scale and degree of individual coding projects will vary. If you already have some programming experience, you may want to develop a larger, more intensive project. If you’re new to coding, your project may borrow code and ideas from class and apply them to different data or variables. In either case, the goal is simply to practice your coding skills and develop greater familiarity with Python.
#
# It is completely fine if parts of your initial plans for the individual coding project prove more difficult or complicated than you anticipated. While you will need to submit executable code as part of the project, it is also important to document and describe what didn’t work. What proved too time-consuming? What parts of coding in Python were challenging? These details should be included in your submissions alongside your final code versions.
#
# The Individual Coding Project is worth 40% of your overall grade. It is split into three parts: the Topic Statement, the Demonstration of Code, and the Project Showcase. For more info, see the [Individual Project Directions.](https://github.com/dlab-berkeley/DIGHUM101-2026/blob/main/assignments/individual_project_directions.md)
#
# #### Group Project
#
# The group project allows you to survey a Python-dependent method in the digital humanities and reflect on its broader contributions to the field. The group project also invites you to think about the collaborative nature of the digital humanities–a field where researchers often work in teams or labs and where the work depends on layers of interdependent technologies and resources. There is no coding required for the group project. Instead, you will be studying related papers or projects that use Python to enact the method of your choosing.
#
# The Group Project is worth 40% of your overall grade. It is split into three parts: the Topic Statement, the Short Paper, and the Presentation. For more info, see the [Group Project Directions.](https://github.com/dlab-berkeley/DIGHUM101-2026/blob/main/assignments/group_project_directions.md)
#
# #### Final Video Reflection
#
# At the end of the course, you will submit a brief video (3-5 minutes) reflecting on your experiences and taking inventory of your personal development as a programmer with Python. This video reflection is a simple way to describe what you’ve learned and how you may or may not pursue Python in the digital humanities moving forward.
#
# The Final Video Reflection is worth 10% of your overall grade.
#
# ### Schedule
#
# | Week | Date | Topics |
# |------|------|---------|
# | 1 | May 25 | NO CLASS – Memorial Day |
# | 1 | May 26 | Syllabus, major assignments, setup, getting started |
# | 1 | May 27 | Vocabulary, data types & structures, reading errors, libraries |
# | 1 | May 28 | Pandas intro, Project workday (group assignments, brainstorming topics) |
# | 2 | June 1 | Functions, conditionals, iterations |
# | 2 | June 2 | Pandas overview |
# | 2 | June 3 | Text analysis, regular expressions, preprocessing, tokenization, word frequency analysis |
# | 2 | June 4 | Project workday: choosing methods, identifying datasets |
# | 3 | June 8 | Text analysis continued, n-grams, pos-tagging, TF-IDF |
# | 3 | June 9 | Data visualization |
# | 3 | June 10 | Web scraping, APIs |
# | 3 | June 11 | Project workday: group project collaboration |
# | 4 | June 15 | Web scraping, APIs continued |
# | 4 | June 16 | Network Analysis, Geospatial data |
# | 4 | June 17 | Machine learning intro, topic modelling, text classification |
# | 4 | June 18 | Project workday: individual project time |
# | 5 | June 22 | Machine learning continued, sentiment analysis, NER, word embeddings |
# | 5 | June 23 | Machine learning continued, Transformers, BERT |
# | 5 | June 24 | Transformers, LLMs, coding with LLMs |
# | 5 | June 25 | Project workday: group project collaboration, individual project time |
# | 6 | June 29 | Asynchronous – individual project showcase |
# | 6 | June 30 | Asynchronous – individual project showcase feedback |
# | 6 | July 1 | Group presentations |
# | 6 | July 2 | Group presentations |
#
# ### Assignment Due Dates
#
# | Week | Assignments Due |
# |------|-----------------|
# | 1 | None |
# | 2 | Individual Project: Topic Statement Due Friday, June 5 at 11:59pm |
# | 3 | Group Project: Topic Statement Due Friday, June 12 at 11:59pm |
# | 4 | None |
# | 5 | Individual Project: Demonstration of Code Due Sunday, June 28 at 11:59pm |
# | 6 | Individual Project: Recorded Showcase Due Monday, June 29 at 12:00pm<br>Individual Project: Showcase Feedback Due Tuesday, June 30 at 11:59pm<br>Group Project: Presentation Due Wednesday, July 1 at 1:00pm<br>Group Project: Short Paper Due Friday, July 3 at 11:59pm<br>Final Video Reflection Due Friday, July 3 at 11:59pm |
#
# ### AI Policy
#
# Large Language Models (LLMs) are creating dynamic, wide-ranging impacts for programmers and researchers. In just the past year, several frontier models have gained high capacity to generate functional code. We will be discussing these developments and LLMs in class. Using LLMs is not strictly prohibited, but there are three important considerations to bear in mind:
#
# 1) _Responsibility:_ The responsibility for all submitted work, whether text or code, lies with you. You should be ready to demonstrate your understanding of it and ensure that you have verified its accuracy.
# 2) _Honesty:_ Honesty regarding your use of these tools is of utmost importance. Submitting automatically generated code or text without appropriate citation will be regarded as plagiarism.
# 3) _Originality:_ While leveraging AI tools for assistance is permissible, the work you submit should predominantly reflect your original ideas, code, and language. Assignments that are in large part copied from an LLM are unlikely to be evaluated well.
#
# In other words, there are permissible uses of AI in this class. It is acceptable to converse with LLMs about coding exercises or coding problems you're having trouble with. It is acceptable to use code generated by LLMs but you must cite your LLM usage and have a complete understanding of any code you submit. The majority of code you submit should also be written by you. Ignoring this policy would result in plagiarism, a serious offense that will be treated accordingly.
#
# Most importantly, though, please remember that this class is meant to help you develop a working knowledge of Python in DH contexts. If you're relying on LLMs for every difficult part in the learning process, you need to pause and reflect. Why are you avoiding the challenging aspects of learning? What is it about the difficult parts that make you feel stuck? No matter how useful LLMs are or become, you'll never be able to code effectively unless you work through the difficult aspects of coding. Please be mindful about your learning processes and how LLM usage could be hindering them.
#
# ## Introductions
#
# Instructor: [Matthew Kollmer](https://matthewkollmer.com)
#
# - professional background
# - teaching background
# - research interests
# - my journey to Python
#
# GSI: Rae Willis-Conger
#
# - professional background
# - teaching background
# - research interests
#
# Students:
#
# Please share the following:
# - name, preferred pronouns
# - What are you studying?
# - Where (geographically) are you joining the course from?
# - What is your experience with coding?
# - What is your experience with the digital humanities?
# - What do you hope to get out of this class?
#
# ## Software Installations and Setup
#
# In an attempt to make it easier to follow along with the course, I've outlined the following steps for software installations and setup. These steps explain some free software and platforms we'll be using. It's worth noting, however, that the most important dependencies are:
#
# - Python
# - GitHub
# - Jupyter Notebooks
#
# If you're already familiar with coding, you may interact with course materials as you see fit–just as long as you have a working Python environment, access to GitHub, and a way to write and run Jupyter Notebooks.
#
# If all this sounds completely unfamiliar to you, then you should follow the __software installations and setup__ guide. Here's a complete breakdown:
#
# ### 1) Anaconda
#
# Anaconda is a free, open-source software suite used by data scientists, researchers, and programmers. You can think of it like Microsoft Office but for programming. It has lots of utility, but for our purposes, it's crucial to set up what's called a __Python environment__.
#
# What's a Python environment? You can think of it like an isolated workspace on your computer, a specific directory that brings together these elements:
#
# - a __Python interpreter__–the specific version of Python you're using. Python, like most anything run on computers, gets updated. Your Python interpreter is the version copy of Python that compiles and runs your code.
# - the __standard library__-the essential Python functions that are built-in to the Python interpreter. You can think of the standard Python library as a core collection of tools in Python. It allows you to interact with files, do math, randomize variables–all sorts of stuff.
# - other __libraries__–we'll go over libraries in great detail throughout the class, but in a nutshell: they are collections of pre-written code intended to handle specific tasks. They are extensions of the standard library for specific use-cases (everything from scraping web data to machine learning). When you set up a Python environment, it's often helpful to choose the libraries you know you'll be using and download them into the environment from the start.
#
# So, basically, we're using __Anaconda__ to create a __Python environment__ specifically designed for this class. To install Anaconda, follow these steps:
#
# 1) Go to [https://www.anaconda.com/download/success](https://www.anaconda.com/download/success)
# 2) Navigate to your device type (Mac or Windows)
# 3) Download __Miniconda__
#     - You could download Anaconda Distribution instead, but it shouldn’t be necessary for this class. For more info about the differences, see here: [https://www.anaconda.com/docs/getting-started/concepts/anaconda-or-miniconda](https://www.anaconda.com/docs/getting-started/concepts/anaconda-or-miniconda)
#     - If when you attempt to download Miniconda, you get an error message that reads something like "you can't download to this device", it probably means you're on an older device that, as of April 2026, is no longer compatible with the latest versions of Anaconda. Try going to [https://repo.anaconda.com/miniconda/](https://repo.anaconda.com/miniconda/). Then choose the file that matches your type of device and also ends with “.pkg”. This will allow you to download a past version of Anaconda suitable to your device.
# 4) Click through the installation setup
#
# ### 2) GitHub
#
# GitHub is a free online platform for hosting, sharing, and collaborating on code. It's sort of like Google Drive for coders. With a free account, you'll be able to download the course materials and submit assignments as __GitHub Repositories__. These repositories are just clearly delineated places where any related code, data, and other files are stored for a given project.
#
# Creating a GitHub account is easy. All you need to do is:
#
# 1) Go to [https://github.com/](https://github.com/)
# 2) Click “sign up” in the top right corner
# 3) Create your account with username and password
#     - Optional: apply for a [GitHub Education account](https://docs.github.com/en/education/about-github-education/github-education-for-students/apply-to-github-education-as-a-student). This will give you free access to more GitHub resources and tools. You can learn more about GitHub Education here: [https://github.com/education/students](https://github.com/education/students)
#
# ### 3) VS Code
#
# Visual Studio (VS) Code is a free code editor. It's like Microsoft Word or Google Docs for coding. It allows you to draft code, text, edit files, and execute code all on one interface. It's probably the most popular code editor. We'll be using it to draft and interact with course materials. VS Code also conveniently syncs to GitHub accounts.
#
# To set up VS Code, follow these steps:
#
# 1) Visit VS Code: [https://code.visualstudio.com/](https://code.visualstudio.com/)
# 2) Click “download” for your device
# 3) Follow the download directions
# 4) Open VS Code and select “Continue with GitHub”
# 5) Sign into VS Code with your GitHub account
#
# ### 4) Git and the Terminal
#
# At this point, you're about all set up. You have __Anaconda__ ready to set up a Python environment. You have a __GitHub__ account so you can interact with the course online materials. And you have __VS Code__ to do the actual coding in Python.
#
# We still need to synchronize all these components, though. This is admittedly a little more complicated than simply downloading and installing stuff. There are a few ways to do it, but one common practice in programming is using __Git__ in the __Terminal.__
#
# Git is a __versional control system__–a tool that tracks, organizes, and manages changes to files. GitHub is an online platform extension of Git (a place online where Git commands can reach files). Git doesn't have a typical user interface. To use it, you must enter commands into the __Terminal__. The terminal is what a lot of people imagine when they think of coding. It's that non-descript window on the computer with line-by-line executions of code.
#
# The Terminal may seem intimidating, but fear not: with Git, you only need to consider a specific selection of commands.
#
# 1) Open the Terminal - Once you're in VS Code, look to the top menu bar. You should see a dropdown menu option called "Terminal." Click it, and then select "New Terminal." This should open a Terminal at the bottom of VS Code.
# 2) In the Terminal, copy and paste this line of text:
#
# ```bash
# git clone https://github.com/dlab-berkeley/DIGHUM101-2026.git
# ```
#
#
# 3) Press enter. This should download a folder called DIGHUM101-2026 onto your computer. __In VS Code, click  File, select Open..., navigate to the DIGHUM101-2026 folder, and open it. You must do this before continuing.__
#     - Note for Mac users: the first time you use Git, your computer may ask you to install “Command Line Developer Tools.” Click “install” and wait for the installation to finish. This gives your computer access to the git command needed to clone the course repository.
#     - Note for PC users: if you get a response that says something like "The term 'git' is not recognized...", you need to download Git on your laptop, too. Go to [Git Microsoft download](https://git-scm.com/install/windows) and download Git for Windows. If prompted during installation, make sure you select any options that read something like this: "Git from the command line and also from 3rd-party software". Then try the "Git clone" line again.
# 4) At this point, you might be all set up. Depending on your device, VS Code may automatically configure your Python environment using the [environment.yml](https://github.com/dlab-berkeley/DIGHUM101-2026/blob/main/environment.yml) file in the course download. You can test if you're all set up by opening our current notebook (week_1/1-1_setup.ipynb), setting the Kernel (see top right corner of notebook) to "dighum101", and then attempting to run this code:

# %%
# <-- run arrow should be to the left of this line, just outside the code block
# to run this code, press the "run" arrow

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_facecolor("#f5f0e6")
fig.patch.set_facecolor("#f5f0e6")
ax.text(
    0.5, 0.6,
    "Welcome to DIGHUM101!",
    ha="center",
    va="center",
    fontsize=36,
    fontweight="bold"
)

ax.text(
    0.5, 0.38,
    "Digital Humanities + Python",
    ha="center",
    va="center",
    fontsize=20
)

ax.axis("off")
plt.show()

# %% [markdown]
# Did it work? If so, hooray! You're all set up.
#
# 5) If your device didn't automatically set up the environment, copy and paste the following line in the Terminal. This will make sure you're in the DIGHUM101-2026 course directory.
#
# ```bash
# cd DIGHUM101-2026
# ```
#
#
# 6) Press enter. Then copy and paste the following line in the Terminal. This will tell your computer to use Conda to create the Python environment using the environment.yml file in the course download.
#
# ```bash
# conda env create -f environment.yml
# ```
#
#
# 7) Press enter. Now you just need to activate the environment. To do that, copy and paste this text into the Terminal:
#
# ```bash
# conda activate dighum101
# ```
#
#
# Now see if you can run the code from above. Open week_1/1-1_setup.ipynb, set the Kernel to "dighum101" and then press the run arrow to the right of the code block.
#
# ### Final Setup Notes
#
# Git giving you trouble? It's not the only way to download course materials. You can also visit the [course GitHub Repository](https://github.com/dlab-berkeley/DIGHUM101-2026). There should be a green button that says "<> Code". Click it, then select "Download Zip". Once downloaded, unzip the course materials somewhere on your computer that you'll remember. Then you just need to open the course materials in VS Code and try steps six and seven of the above Git and the Terminal directions.
#
# If you want to know more about Git and using the Terminal, [check out this resource](https://github.com/dlab-berkeley/DIGHUM101-2026/blob/main/resources/bash-git_tips.md) in the course resources section. You can do a lot with your computer using the Terminal! That's not strictly something we'll cover in this class, but for those inclined, feel free to read and learn more.
#
# There is one other useful Git command for the class, though. At various times, I may update course materials. If you want to download the latest materials in one shot, open DIGHUM101-2026 in VS Code and then open the Terminal and enter this text:
#
# ```bash
# git pull
# ```
#
#
# That will "pull" all the latest course files onto your device. Easy-peasy! __One important note, though:__ this __will write over files with the same name.__ If you're editing stuff without saving new versions, you may lose your work with "git pull". So, I'd suggest writing your own files for anything you need to maintain.

# %%
print("That's all, folks!")
