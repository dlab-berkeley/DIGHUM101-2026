# %% [markdown]
# # 2-3: Text Analysis Exercises
#
# This notebook gives you short practice exercises for the text-analysis concepts in `2-3_text_analysis_intro.ipynb`.
#
# You'll work with `frankenstein.txt` in the `data` folder. Work through the cells in order because later exercises use variables you create earlier in the notebook.

# %% [markdown]
# ## Setup and File Paths

# %% [markdown]
# ### Exercise 1: Import text-analysis libraries
#
# Import the same libraries used at the start of the tutorial notebook:
#
# - `punctuation` from `string`
# - `pandas` as `pd`
# - `matplotlib.pyplot` as `plt`
# - `nltk`
# - `stopwords` from `nltk.corpus`

# %%
# Import punctuation from string below

# Import pandas as pd below

# Import matplotlib.pyplot as plt below

# Import nltk below

# Import stopwords from nltk.corpus below

# %% [markdown]
# ### Exercise 2: Inspect punctuation and stop words
#
# Print the `punctuation` variable and its length. Then create a list called `stop_words` using `stopwords.words("english")`, print the list, and print its length.

# %%
# Print punctuation and its length below


# Create an English stop word list below


# Print stop_words and its length below

# %% [markdown]
# ### Exercise 3: Open the Frankenstein text file
#
# Import `os`, check your current working directory with `os.getcwd()`, then use `open()` to open `../data/frankenstein.txt` with `encoding="utf-8-sig"`.
#
# Save the open file object as `frankenstein_file`.

# %%
# Import os below


# Check your current working directory below


# Open the Frankenstein text file below
frankenstein_path = "../data/frankenstein.txt"

# %% [markdown]
# ### Exercise 4: Read the raw text
#
# Use `.read()` to read `frankenstein_file` into a variable called `frankenstein_raw`. Then close the file.
#
# Print the type, length, and first 1000 characters of `frankenstein_raw`.

# %%
# Read the file into frankenstein_raw below


# Close the file below


# Print the type, length, and first 1000 characters below

# %% [markdown]
# ### Exercise 5: Find the Project Gutenberg markers
#
# Create `start_marker` and `end_marker` using the strings below. Then use `.find()` to create `start_index` and `end_index`.
#
# Print both index numbers.

# %%
start_marker = "*** START OF THIS PROJECT GUTENBERG EBOOK FRANKENSTEIN ***"
end_marker = "End of the Project Gutenberg EBook of Frankenstein"

# Use .find() to create start_index and end_index below


# Print start_index and end_index below

# %% [markdown]
# ### Exercise 6: Slice out the main Gutenberg body
#
# Use `start_index`, `end_index`, and `len(start_marker)` to slice the raw text. Save the result as `frankenstein_body` and use `.strip()` to remove extra whitespace.
#
# Print the length and first 1000 characters of `frankenstein_body`.

# %%
# Slice the text between the Gutenberg markers below


# Print the length and first 1000 characters below

# %% [markdown]
# ### Exercise 7: Slice out the novel itself
#
# Use `.find()` to locate the real beginning of the novel inside `frankenstein_body`.
#
# Search for this string: `"Letter 1
#
# _To Mrs. Saville, England._"`
#
# Then slice from that index to the end and save the result as `frankenstein`.

# %%
# Use .find() to mark the start of the novel below


# Slice from novel_start to the end of the document below


# Check the length of frankenstein below

# %% [markdown]
# ### Exercise 8: Check the beginning and ending
#
# Print the first 1000 characters and the last 1000 characters of `frankenstein`.

# %%
# Print the first 1000 characters below


# Print the last 1000 characters below

# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# ### Exercise 9: Count characters, words, lines, and periods
#
# Use the same methods from the tutorial to print:
#
# - the number of characters with `len()`
# - the number of words from a simple `.split()`
# - the number of lines from `.split("
# ")`
# - the number of periods with `.count(".")`

# %%
# Print characters, words from simple split, lines, and periods below

# %% [markdown]
# ### Exercise 10: Split on periods
#
# Use `.split(".")` to count how many pieces of text are created when `frankenstein` is split on periods.

# %%
# Print the number of pieces after splitting on periods below

# %% [markdown]
# ### Exercise 11: Create a small sample
#
# Create a variable called `sample` that contains the first 1200 characters of `frankenstein`. Print the sample.

# %%
# Create a sample from the first 1200 characters below


# Print sample below

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### Exercise 12: Tokenize with `.split()`
#
# Use `.split()` to tokenize `sample`. Save the result as `raw_tokens`.
#
# Print the first 80 tokens and the number of tokens in the sample.

# %%
# Tokenize sample with .split() below


# Print the first 80 tokens and the token count below

# %% [markdown]
# ### Exercise 13: Tokenize the full novel with `.split()`
#
# Use `.split()` to tokenize the full `frankenstein` string. Save the result as `frankenstein_raw_tokens`.
#
# Print the first 40 tokens and the total number of raw tokens.

# %%
# Tokenize the full Frankenstein text with .split() below


# Print the first 40 tokens and the total raw token count below

# %% [markdown]
# ### Exercise 14: Tokenize with NLTK
#
# Download the NLTK tokenizer data if needed. Then use `nltk.word_tokenize()` on both `sample` and the full `frankenstein` text.
#
# Save the results as `nltk_sample_tokens` and `frankenstein_nltk_tokens`. Print the first few tokens and compare the token counts to the `.split()` counts.

# %%
# If this is your first time using nltk tokenization on this computer,
# you may need to download the tokenizer data.
nltk.download("punkt")
nltk.download("punkt_tab")

# Tokenize sample with nltk.word_tokenize() below


# Tokenize the full Frankenstein text with nltk.word_tokenize() below


# Print token samples and compare counts below

# %% [markdown]
# ## Counting Words

# %% [markdown]
# ### Exercise 15: Count unique words with `set()`
#
# Create `raw_unique_words` from `frankenstein_raw_tokens`. Then create `lowercase_unique_words` by lowercasing `frankenstein` before splitting and converting to a set.
#
# Print both counts.

# %%
# Create a set of unique raw words below


# Create a set of unique lowercase words below


# Print both counts below

# %% [markdown]
# ### Exercise 16: Count unique words with `FreqDist`
#
# Create two NLTK frequency distributions:
#
# - `raw_freq_dist` from `frankenstein_raw_tokens`
# - `lowercase_freq_dist` from `frankenstein.lower().split()`
#
# Print the lengths of the sets and frequency distributions so you can compare them.

# %%
# Create a frequency distribution from the raw tokens below


# Create a frequency distribution from lowercase tokens below


# Print the set and FreqDist counts below


# Print the type of raw_unique_words and raw_freq_dist below

# %% [markdown]
# ## Cleaning Text

# %% [markdown]
# ### Exercise 17: Remove punctuation
#
# Create `frankenstein_clean` by lowercasing `frankenstein`. Then use a `for` loop over `punctuation` and `.replace()` to remove punctuation.
#
# Print the first 1000 characters of the cleaned text.

# %%
# Lowercase the full Frankenstein text below


# Use a for loop to remove punctuation below


# Print the first 1000 characters of frankenstein_clean below

# %% [markdown]
# ### Exercise 18: Tokenize the cleaned text and calculate type-token ratio
#
# Use `.split()` to tokenize `frankenstein_clean` as `frankenstein_tokens`. Then calculate:
#
# - `total_words`
# - `unique_words`
# - type-token ratio, which is `unique_words / total_words`

# %%
# Tokenize the cleaned text below


# Calculate total words and unique words below


# Print the first 40 clean tokens, total words, unique words, and type-token ratio below

# %% [markdown]
# ## Frequencies and Stop Words

# %% [markdown]
# ### Exercise 19: Remove stop words
#
# First tokenize `frankenstein_clean` with `nltk.word_tokenize()` and create `frankenstein_nltk_freq_dist_clean` with `nltk.FreqDist()`.
#
# Then create a new `FreqDist` called `frankenstein_no_stops_freq_dist`. Loop through the cleaned frequency distribution and keep only words that are not in `stop_words`.
#
# Display the 20 most common non-stop words.

# %%
# Tokenize the cleaned Frankenstein text with nltk below


# Create a clean frequency distribution below


# Create a new FreqDist for words that are not stop words below


# Loop through the clean frequency distribution and keep non-stop words below


# Display the 20 most common non-stop words below

# %% [markdown]
# ### Exercise 20: Make a frequency dataframe, plot it, and search word counts
#
# Use `pd.DataFrame()` to turn the 25 most common non-stop words into a dataframe called `frequency_df` with columns called `"word"` and `"count"`.
#
# Then create a bar plot like the one in the tutorial.
#
# Finally, create a `search_words` list and use a `for` loop to print the count for each word. You can use these words or choose your own: `"frankenstein"`, `"creature"`, `"monster"`, `"victor"`, `"elizabeth"`, `"walton"`.

# %%
# Create frequency_df from the 25 most common non-stop words below


# View frequency_df below


# Plot frequency_df as a bar chart below


# Create a search_words list below


# Loop through search_words and print each word with its count below
