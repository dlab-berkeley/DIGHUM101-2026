# %% [markdown]
# # 3-2: Data Visualization Exercises
#
# In this exercise notebook, you'll practice the visualization examples from the 3-2 tutorial.
#
# The notebook uses the same Gapminder dataset for histogram, box plot, and scatter plot practice. For the text-based bar plot examples, you'll use a different human-rights report: `../data/human-rights/bangladesh2013.txt`.

# %% [markdown]
# ## Setup
#
# Run this cell before starting the exercises. It imports the libraries used in the tutorial and sets up the stop words used later in the word-frequency plots.

# %%
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns

from collections import Counter
from string import punctuation

import nltk
from nltk.corpus import stopwords

nltk.download("stopwords", quiet=True)
stop_words = set(stopwords.words("english"))

plt.style.use("seaborn-v0_8-bright")

# %% [markdown]
# ## Loading The Gapminder Dataset

# %% [markdown]
# ### Exercise 1
#
# Load the Gapminder CSV file from `../data/gapminder-FiveYearData.csv` into a dataframe called `gap`.
#
# Then display the first few rows.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2
#
# Print the shape of `gap`, then check the data types for each column.

# %%
# Your code here

# %% [markdown]
# ## Histograms

# %% [markdown]
# ### Exercise 3
#
# Create histograms for all numeric columns in `gap` using the Pandas `.hist()` method.
#
# Then try the same plot again with a larger figure size.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4
#
# Create a histogram for only the `lifeExp` column.
#
# Use a figure size of `(8, 4)` and choose a color.

# %%
# Your code here

# %% [markdown]
# ### Exercise 5
#
# Sort `gap` by `lifeExp` in ascending order and save the first 10 rows as `top_10_lowest`.
#
# Then display `top_10_lowest`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 6
#
# Use `top_10_lowest` to create a horizontal bar plot of the 10 lowest life expectancy values in the full dataset.
#
# Use `plt.barh()`, and label the x-axis, y-axis, and title.

# %%
# Your code here

# %% [markdown]
# ### Exercise 7
#
# Find the latest year in the Gapminder dataset and save it as `latest_year`.
#
# Then create a new dataframe called `gap_latest` that contains only rows from that year.

# %%
# Your code here

# %% [markdown]
# ### Exercise 8
#
# Using `gap_latest`, find the 10 countries with the lowest life expectancy in the latest year.
#
# Save the result as `top_10_lowest_latest`, then create a horizontal bar plot from it.

# %%
# Your code here

# %% [markdown]
# ### Exercise 9
#
# Create a Matplotlib histogram of `gdpPercap` from `gap_latest`.
#
# Use 30 bins, then add a title, x-axis label, and y-axis label.

# %%
# Your code here

# %% [markdown]
# ### Exercise 10
#
# Create the same `gdpPercap` histogram using the Pandas `.hist()` method.
#
# Use 30 bins and turn the grid off.

# %%
# Your code here

# %% [markdown]
# ### Exercise 11
#
# Create the same `gdpPercap` histogram using Seaborn's `histplot()`.
#
# Use 30 bins and add a title and axis labels.

# %%
# Your code here

# %% [markdown]
# ### Exercise 12
#
# Create another Seaborn `histplot()` for `gdpPercap`, this time with `kde=True`.
#
# This adds a kernel density estimate line to the histogram.

# %%
# Your code here

# %% [markdown]
# ## Bar Plots With Text Data

# %% [markdown]
# ### Exercise 13
#
# Open `../data/human-rights/bangladesh2013.txt` and save the contents as a string called `bangladesh`.
#
# Then print the number of words in the report and the first 500 characters.

# %%
# Your code here

# %% [markdown]
# ### Exercise 14
#
# Tokenize `bangladesh` by splitting on whitespace.
#
# Save the result as `bangladesh_tokens`, then print the first 25 tokens.

# %%
# Your code here

# %% [markdown]
# ### Exercise 15
#
# Use `Counter` to count the words in `bangladesh_tokens`.
#
# Then save the 12 most common words as `bangladesh_barplot` and display the result.

# %%
# Your code here

# %% [markdown]
# ### Exercise 16
#
# Convert `bangladesh_barplot` into a dataframe called `bangladesh_df` with two columns: `Word` and `Frequency`.
#
# Then display the dataframe.

# %%
# Your code here

# %% [markdown]
# ### Exercise 17
#
# Create a vertical bar plot from `bangladesh_df`.
#
# Use `Word` for the x-axis and `Frequency` for the y-axis.

# %%
# Your code here

# %% [markdown]
# ### Exercise 18
#
# Create a horizontal bar plot from `bangladesh_df`.
#
# Add labels and a title, and invert the y-axis so the most frequent word appears at the top.

# %%
# Your code here

# %% [markdown]
# ## Cleaning Text Before Plotting

# %% [markdown]
# ### Exercise 19
#
# Create a lowercase version of the Bangladesh report called `bangladesh_lower`.
#
# Then remove punctuation by looping over `punctuation` and replacing each punctuation character with an empty string.

# %%
# Your code here

# %% [markdown]
# ### Exercise 20
#
# Tokenize `bangladesh_lower` and remove stop words.
#
# Use the list-comprehension pattern from the tutorial. Save the result as `bangladesh_tokens_cleaned`, then print the first 25 tokens.

# %%
# Your code here

# %% [markdown]
# ### Exercise 21
#
# Count the 12 most common words in `bangladesh_tokens_cleaned`.
#
# Save the result as `bangladesh_barplot_cleaned`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 22
#
# Convert `bangladesh_barplot_cleaned` into a dataframe called `bangladesh_df_cleaned` with two columns: `Word` and `Frequency`.
#
# Then create a horizontal bar plot from the cleaned word counts.

# %%
# Your code here

# %% [markdown]
# ## Box Plots

# %% [markdown]
# ### Exercise 23
#
# Create a box plot of `lifeExp` for the entire Gapminder dataset.

# %%
# Your code here

# %% [markdown]
# ### Exercise 24
#
# Create a box plot of `lifeExp` grouped by `continent`.
#
# Use the `by` argument from the tutorial.

# %%
# Your code here

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# ### Exercise 25
#
# Create a Pandas scatter plot with `lifeExp` on the x-axis and `gdpPercap` on the y-axis.
#
# Add an x-axis label, y-axis label, and title.

# %%
# Your code here

# %% [markdown]
# ### Exercise 26
#
# Create the same scatter plot using Seaborn's `scatterplot()`.
#
# Use a small marker, like `marker="."`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 27
#
# Use Seaborn's `FacetGrid` to create a grid of scatter plots by continent.
#
# Map `plt.scatter` onto the grid with `lifeExp` on the x-axis and `gdpPercap` on the y-axis.

# %%
# Your code here

# %% [markdown]
# ## Exporting Figures

# %% [markdown]
# ### Exercise 28
#
# Create a vertical bar plot from `bangladesh_df_cleaned` and save it as `bangladesh_barplot_example.jpg`.
#
# Rotate the x tick labels 45 degrees, align them to the right, and use `bbox_inches="tight"` so the labels are not cut off.

# %%
# Your code here
