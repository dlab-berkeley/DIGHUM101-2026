# %% [markdown]
# # 4-1: NYT API Exercises
#
# This notebook gives you beginner-friendly practice with the NYT API code from `../week_4/4-1_api_lessons.ipynb`.
#
# Work through the cells in order. Each exercise follows the same Python pattern used in the tutorial notebook, but asks you to make a small change: a different NYT section, query, date range, or result variable. If you get stuck, look back at the matching code cells in the lesson notebook.
#
# **Important:** Never print or share your API key.

# %% [markdown]
# ## Setup
#
# Run the setup cells before beginning the exercises. These cells import the same libraries used in the tutorial, install `pynytimes` if needed, and retrieve your NYT API key without displaying it.

# %%
# Import required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
from datetime import datetime

# libraries configparser and getpass to keep API key hidden
import configparser
import os
from getpass import getpass

# %%
def get_api_key(api_name):
    config_file_path = os.path.expanduser("~/.notebook-api-keys")
    config = configparser.ConfigParser(interpolation=None)
    
    if os.path.exists(config_file_path):
        config.read(config_file_path)
    
    if config.has_option("API_KEYS", api_name):
        update_key = input(f"An API key for {api_name} already exists. Do you want to update it? (y/n): ").lower()
        if update_key == 'n':
            return config.get("API_KEYS", api_name)
    
    api_key = getpass(f"Enter your {api_name} API key: ")

    if not config.has_section("API_KEYS"):
        config.add_section("API_KEYS")
    config.set("API_KEYS", api_name, api_key)
    
    with open(config_file_path, "w") as f:
        config.write(f)
    
    return api_key

api_key = get_api_key("NYT")

print("NYT API key retrieved successfully.")

# %%
# %pip install pynytimes

# %%
from pynytimes import NYTAPI

nyt = NYTAPI(api_key, parse_dates=True)

# %% [markdown]
# ## Top Stories API
#
# ### Exercise 1: Get Top Stories From The Home Page
#
# Recreate the tutorial cell that calls `nyt.top_stories()` with no section argument.
#
# Save the result as `home_top_stories`, then print a sentence that includes the length of the list.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2: Preview The First Two Stories
#
# Use list slicing to preview the first two items in `home_top_stories`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3: Inspect One Story
#
# Save the first item in `home_top_stories` as `home_top_story`, then display it.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4: Request The Section List
#
# Recreate the tutorial's `requests.get()` example for the NYT section-list endpoint.
#
# Import `requests`, create the `url`, create the `params` dictionary with your API key, make the request, and save `response.json()` as `sections_data`. Display `sections_data`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 5: Get Top Stories From A Different Section
#
# The tutorial requests top stories from the `arts` section. Recreate that pattern, but request the `science` section instead.
#
# Save the result as `top_science_stories`, print the section of the first story, then display the first story.

# %%
# Your code here

# %% [markdown]
# ### Exercise 6: Choose Another Section
#
# Choose one different NYT section, such as `books`, `travel`, `sports`, `food`, `technology`, or `world`.
#
# Create a variable called `section`, use it in `nyt.top_stories(section=section)`, save the result as `top_section_stories`, and print how many stories were returned.

# %%
# Your code here

# %% [markdown]
# ### Exercise 7: Get The First Title From Your Section
#
# Save the first story from `top_section_stories` as `top_section_story`.
#
# Then save its title as `top_section_story_title` and display the title.

# %%
# Your code here

# %% [markdown]
# ## Organizing API Results With `pandas`
#
# ### Exercise 8: Convert Top Stories To A DataFrame
#
# Use `pd.json_normalize()` to convert `top_section_stories` into a DataFrame called `section_df`.
#
# Then use `.head()` to view the first five rows.

# %%
# Your code here

# %% [markdown]
# ### Exercise 9: Inspect DataFrame Metadata
#
# Use `.info()` to inspect `section_df`.

# %%
# Your code here

# %% [markdown]
# ## Most Viewed And Most Shared APIs
#
# ### Exercise 10: Retrieve The Most Viewed Articles Today
#
# Recreate the tutorial cell that calls `nyt.most_viewed()`.
#
# Save the result as `most_viewed_today`, print the first article's title and section, then display the first article.

# %%
# Your code here

# %% [markdown]
# ### Exercise 11: Count The Most Viewed Articles
#
# Use `len()` to check how many articles are in `most_viewed_today`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 12: Retrieve Popular Articles From A Longer Period
#
# The tutorial retrieves the most viewed articles from the last 7 days. Recreate that pattern, but use `days=30`.
#
# Save the result as `most_viewed_month`, then display the title of the first article.

# %%
# Your code here

# %% [markdown]
# ## Article Search API With `pynytimes`
#
# ### Exercise 13: Search For Articles About A New Topic
#
# The tutorial searches for articles about `Berkeley`.
#
# Search for a different topic, such as `climate change`, `artificial intelligence`, `music`, or a topic of your choice. Save the results as `topic_articles`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 14: Collect The Main Headlines
#
# Use a list comprehension to collect each article's main headline from `topic_articles`.
#
# Save the list as `topic_headlines`, then display it.

# %%
# Your code here

# %% [markdown]
# ### Exercise 15: Inspect The First Search Result
#
# Save the first article in `topic_articles` as `topic_article`.
#
# To make the result easier to read, remove the `multimedia` key if it exists. Then display `topic_article`.
#
# Hint: `topic_article.pop("multimedia", None)` removes the key without causing an error if the key is missing.

# %%
# Your code here

# %% [markdown]
# ### Exercise 16: Search Within A Date Range
#
# Recreate the tutorial's date-range article search, but use a different topic and different dates.
#
# For example, you could search for `covid vaccines` from January 1, 2021 to March 1, 2021.
#
# Create `begin` and `end` as `datetime` objects, put them in `date_dict`, and pass `dates=date_dict` to `nyt.article_search()`. Save the result as `dated_articles`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 17: Inspect And Count Date-Range Results
#
# Save the first item from `dated_articles` as `dated_article`, remove its `multimedia` key if it exists, and display it.
#
# Then use `len()` to check how many articles were returned.

# %%
# Your code here

# %% [markdown]
# ### Exercise 18: Use `help()` On Article Search
#
# Use Python's `help()` function to inspect `nyt.article_search`, just like in the tutorial.

# %%
# Your code here

# %% [markdown]
# ## Article Search API With `requests`
#
# ### Exercise 19: Use The Updated Request-Based Search Pattern
#
# Recreate the tutorial's direct `requests` version of Article Search, but make these changes:
#
# - Use a new `QUERY`, such as `digital humanities`, `climate change`, or `public libraries`.
# - Use your own `begin` and `end` dates.
# - Set `max_pages = 2` so you only request up to 20 articles.
# - Keep the `time.sleep(10)` line so your requests are spaced out.
#
# Print the total number of articles fetched and preview the first five headlines and URLs.

# %%
# Your code here

# %% [markdown]
# ## Loading Saved NYT Data
#
# ### Exercise 20: Load And Inspect The Election Articles CSV
#
# Recreate the final tutorial cells that load the previously saved NYT article data.
#
# Use `pd.read_csv()` to load `../data/election2020_articles.csv` into a DataFrame called `election_df`. Then use `.head()`, `.info()`, and `len()` to inspect it.

# %%
# Your code here
