# %% [markdown]
# # 3-1: Text Analysis Exercises x2
#
# In this exercise notebook, you'll practice many of the techniques from the 3-1 tutorial, but with a different corpus: four novels by Charles Dickens.
#
# Use the tutorial notebook as your model. Most exercises can be solved by adapting the Austen code, changing the dataframe name to `dickens_texts`, and working with `../data/dickens_texts.csv`.

# %% [markdown]
# ## Setup
#
# Run this cell before starting the exercises. It imports the libraries used in the tutorial and downloads the small NLTK resources needed for tokenization, stop words, and POS tagging.

# %%
from string import punctuation
import re

import pandas as pd
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk.util import ngrams

from sklearn.feature_extraction.text import TfidfVectorizer

# nltk resources used in this notebook
nltk.download("punkt", quiet=True)
nltk.download("punkt_tab", quiet=True)
nltk.download("stopwords", quiet=True)
nltk.download("averaged_perceptron_tagger_eng", quiet=True)

stop_words = set(stopwords.words("english"))

# %% [markdown]
# ## Loading And Inspecting The Corpus

# %% [markdown]
# ### Exercise 1
#
# Load `../data/dickens_texts.csv` into a dataframe called `dickens_texts`. Then display the first few rows.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2
#
# Print the number of rows in `dickens_texts`, then inspect the dataframe's data types.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3
#
# Display only the `title`, `year_published`, and `author` columns. This is a quick way to check the metadata for the corpus.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4
#
# Create a new column called `string_length` that stores the number of characters in each row's `full_text` value. Then display the `title` and `string_length` columns.

# %%
# Your code here

# %% [markdown]
# ### Exercise 5
#
# Create a rough word count column called `rough_word_count` by splitting each `full_text` string on whitespace and counting the results.
#
# Then display `title` and `rough_word_count`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 6
#
# Make a simple bar plot comparing `rough_word_count` across the Dickens texts. Label the plot clearly.

# %%
# Your code here

# %% [markdown]
# ## Preprocessing A Sample

# %% [markdown]
# ### Exercise 7
#
# Select the `full_text` value for `A Christmas Carol` and save it to a variable called `carol_text`.
#
# Then print the first 300 characters and the last 300 characters.

# %%
# Your code here

# %% [markdown]
# ### Exercise 8
#
# Create a sample from the first 750 characters of `carol_text`. Save it as `carol_sample`.
#
# Then create a lowercase version called `carol_sample_lower` and print the first 500 characters.

# %%
# Your code here

# %% [markdown]
# ### Exercise 9
#
# Create a punctuation string called `all_punctuation` by combining Python's `punctuation` string with this extra punctuation:
#
# ```python
# extra_punctuation = "“”‘’—–"
# ```
#
# Then use a `for` loop to replace each punctuation character in `carol_sample_lower` with a space. Save the result as `carol_sample_clean`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 10
#
# Split `carol_sample_clean` into tokens using `.split()`. Save the result as `carol_sample_tokens` and print the first 50 tokens.

# %%
# Your code here

# %% [markdown]
# ### Exercise 11
#
# Remove stop words from `carol_sample_tokens`.
#
# Use an empty list as an accumulator, loop over the tokens, and append only the tokens that are not in `stop_words`. Save the result as `carol_sample_no_stops`.

# %%
# Your code here

# %% [markdown]
# ## Reusable Preprocessing

# %% [markdown]
# ### Exercise 12
#
# Write a function called `clean_dickens_text()` that:
#
# - takes one text as input
# - lowercases it
# - replaces punctuation in `all_punctuation` with spaces
# - splits the cleaned text into tokens
# - returns the list of tokens
#
# Test the function on `carol_sample`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 13
#
# Apply `clean_dickens_text()` to the `full_text` column and save the results in a new column called `cleaned_text`.
#
# Then create a `word_count` column by counting the number of tokens in each row's `cleaned_text` list.

# %%
# Your code here

# %% [markdown]
# ### Exercise 14
#
# Make a bar plot comparing `word_count` across the Dickens texts. Give the plot a title and label the axes.

# %%
# Your code here

# %% [markdown]
# ## Regular Expressions For Dialogue

# %% [markdown]
# ### Exercise 15
#
# Write a function called `extract_dickens_dialogue()` that uses the tutorial's regular expression pattern to extract quoted passages.
#
# The function should:
#
# - take one text as input
# - replace curly opening and closing quotation marks with straight quotation marks
# - use `re.findall()` to return quoted passages
#
# Test it on `carol_text` by printing the first five quoted passages.

# %%
# Your code here

# %% [markdown]
# ### Exercise 16
#
# Apply `extract_dickens_dialogue()` to the `full_text` column and save the result in a new column called `dialogue`.
#
# Then create two more columns:
#
# - `dialogue_word_count`: approximate word count for the dialogue passages
# - `dialogue_ratio`: `dialogue_word_count` divided by `word_count`
#
# Display the `title`, `word_count`, `dialogue_word_count`, and `dialogue_ratio` columns.

# %%
# Your code here

# %% [markdown]
# ### Exercise 17
#
# Make a bar plot comparing `dialogue_ratio` across the Dickens texts. Use a title that reminds the reader this is an approximate measure.

# %%
# Your code here

# %% [markdown]
# ## N-Grams

# %% [markdown]
# ### Exercise 18
#
# Create a `trigrams` column that stores a `FreqDist` of trigrams for each row's `cleaned_text` tokens.
#
# You can use either the loop pattern or the `.apply()` pattern from the tutorial.

# %%
# Your code here

# %% [markdown]
# ### Exercise 19
#
# Find the top 20 trigrams in `Great Expectations`.
#
# Then convert those top trigrams into a dataframe called `great_expectations_trigrams_df` with two columns: `trigram` and `count`.
#
# Finally, turn the trigram tuples into readable strings by joining the words with spaces.

# %%
# Your code here

# %% [markdown]
# ### Exercise 20
#
# Create a horizontal bar plot showing the top 20 trigrams in `Great Expectations`.

# %%
# Your code here

# %% [markdown]
# ## POS Tagging

# %% [markdown]
# ### Exercise 21
#
# Create a custom punctuation string for POS tagging called `pos_punctuation`.
#
# Start with `all_punctuation`, but keep periods, question marks, exclamation points, straight apostrophes, and curly apostrophes. Then write a function called `tokenize_dickens_for_pos()` that removes only `pos_punctuation` and tokenizes the text with `nltk.word_tokenize()`.
#
# Test the function on `carol_sample`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 22
#
# Use POS tagging to compare broad part-of-speech ratios across the Dickens texts.
#
# Follow the tutorial's pattern:
#
# - define or reuse a function that calls `nltk.pos_tag()`
# - define or reuse a function that counts nouns, proper nouns, adjectives, verbs, and adverbs
# - create a `pos_counts` column
# - expand the dictionaries in `pos_counts` into a new dataframe
# - divide each POS count by `word_count`
# - visualize the ratios in a grouped bar plot

# %%
# Your code here

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# ### Exercise 23
#
# Create a TF-IDF dataframe for the Dickens corpus.
#
# Use the tutorial's pattern:
#
# - create a `TfidfVectorizer` with `stop_words=list(stop_words)` and `max_features=5000`
# - use `.fit_transform()` on `dickens_texts["full_text"]`
# - get the terms with `.get_feature_names_out()`
# - turn the matrix into a dataframe called `dickens_tfidf_df`
# - use the Dickens titles as the dataframe index

# %%
# Your code here

# %% [markdown]
# ### Exercise 24
#
# Write a function called `top_dickens_tfidf_terms()` that returns the top TF-IDF terms for one title.
#
# Then use it to create a bar plot of the top 20 TF-IDF terms in `A Tale of Two Cities`.

# %%
# Your code here
