# %% [markdown]
# # 2-1: Functions, Conditionals, and Iteration Exercises
#
# These exercises practice the same Python ideas from the tutorial notebook:
#
# - using existing functions
# - writing custom functions
# - using parameters and return statements
# - writing `if`, `else`, and `elif` statements
# - using booleans and comparison operators
# - iterating through strings and lists
# - combining loops with conditionals
# - saving results in accumulator variables
#
# Run each code cell after you write your answer.

# %% [markdown]
# ## Exercise 1: Use `round()`
#
# Use `round()` to round `average_rating` to 2 decimal places.

# %%
average_rating = 4.6789

# Write your code below

# %% [markdown]
# ## Exercise 2: Use `sorted()`
#
# Use the sorted() function to arrange the following list in alphabetical order.

# %%
animals = ["zebra", "cat", "elephant", "bear", "dog"]

# Write your code below

# %% [markdown]
# ## Exercise 3: Write a simple conversion function
#
# Write a function called `inches_to_centimeters()` that takes one parameter, `inches`, and returns the number of centimeters. One inch is 2.54 centimeters.

# %%
def inches_to_centimeters(inches):
    # Write your code below

# %% [markdown]
# ## Exercise 4: Call your function
#
# Call `inches_to_centimeters()` on the value `12` and save the result in a variable called `centimeter_result`. Then print the result.

# %%
# Write your code below

# %% [markdown]
# ## Exercise 5: Use a function with a variable
#
# Create a variable called `page_width_inches` and assign it the value `8.5`. Then use your function to convert it to centimeters.

# %%
# Write your code below

# %% [markdown]
# ## Exercise 6: Write a text-preparation function
#
# Write a function called `format_phrase()` that takes one parameter, `phrase`. The function should lowercase the phrase and replace spaces with underscores. Return the changed phrase.

# %%
def format_phrase(phrase):
    # Write your code below

# %% [markdown]
# ## Exercise 7: Call your text-preparation function
#
# Create a variable called `archive_phrase` with the value `"Public Library Collection"`. Then call `format_phrase()` on it.

# %%
archive_phrase = "Public Library Collection"

# Write your code below

# %% [markdown]
# ## Exercise 8: Add a docstring
#
# Rewrite `format_phrase()` with a short docstring that explains what the function does.

# %%
def format_phrase(phrase):
    """
    Write your docstring here.
    """
    # Write your code below

# %% [markdown]
# ## Exercise 9: Basic if-statement
#
# Create a variable called `chapter_count` and assign it the value `42`. Write an if-statement that prints "This book has many chapters!" if `chapter_count` is greater than `30`.

# %%
chapter_count = 42

# Write your code below

# %% [markdown]
# ## Exercise 10: Add or subtract with an if-statement
#
# Create a variable called page_count and assign it the value 45. Write an if statement that adds 10 to page_count if it is less than 50 and prints the page count.

# %%
page_count = 45

# Write your code below

# %% [markdown]
# ## Exercise 11: If-else statement
#
# Create a variable called `year_published` and assign it the value `1925`. If the year is less than `1900`, print `"nineteenth century or earlier"`. Otherwise, print `"twentieth century or later"`.

# %%
year_published = 1925

# Write your code below

# %% [markdown]
# ## Exercise 12: Edit a number with if-else
#
# Create a variable called `score` and assign it the value `87`. If `score` is less than `90`, add `3` to it. Otherwise, subtract `3` from it. Print the final score.

# %%
score = 87

# Write your code below

# %% [markdown]
# ## Exercise 13: Elif practice
#
# Create a variable called `pages` and assign it the value `275`. Write an `if` / `elif` / `else` block that prints:
#
# - `"short"` if pages is less than 150
# - `"medium"` if pages is less than 400
# - `"long"` otherwise

# %%
pages = 275

# Write your code below

# %% [markdown]
# ## Exercise 14: Loop over a list of numbers
#
# Use a loop to print each numberin `my_numbers` rounded to the nearest whole number.

# %%
my_numbers = [120.0456, 305, 87.76, 450.1, 230.609]

# Write your code below

# %% [markdown]
# ## Exercise 15: Check the loop variable after a loop
#
# After looping through `my_numbers`, print the loop variable you used. What value remains after the loop finishes?

# %%
# Write your code below

# %% [markdown]
# ## Exercise 16: Loop over a string
#
# Create a variable called `short_quote` with the value `"read more"`. Use a loop to print each character in the string.

# %%
short_quote = "Life is frittered away by detail... simplify, simplify."

# Write your code below

# %% [markdown]
# ## Exercise 17: Change characters inside a loop
#
# Loop through `short_quote`. For each character, print the original character, then print the uppercase version of that character.

# %%
short_quote = "Life is frittered away by detail... simplify, simplify."

# Write your code below

# %% [markdown]
# ## Exercise 18: Conditional inside a string loop
#
# Loop through the string `"mississippi"`. If the character is `"i"`, print the uppercase version. Otherwise, print the original character.

# %%
river_word = "mississippi"

# Write your code below

# %% [markdown]
# ## Exercise 19: Use `elif` inside a string loop
#
# Loop through the string `"data set"`. If the character is `"a"`, print `"A"`. If the character is a blank space, print `"_"`. Otherwise, print the original character.

# %%
data_phrase = "data set"

# Write your code below

# %% [markdown]
# ## Exercise 20: Accumulator list with numbers
#
# Create a list called `publication_years` with the values `[1818, 1851, 1922, 1952, 2001]`. Create an empty list called `modern_years`. Loop through `publication_years` and add years greater than `1900` to `modern_years`.

# %%
publication_years = [1818, 1851, 1922, 1952, 2001]
modern_years = []

# Write your code below

# %% [markdown]
# ## Exercise 21: Print the accumulator list
#
# Print `modern_years` to see the values you saved.

# %%
# Write your code below

# %% [markdown]
# ## Exercise 22: Accumulator list with strings
#
# Create a list called `author_names` with the values `["Austen", "Baldwin", "Alcott", "Dickens", "Atwood"]`. Create an empty list called `a_authors`. Loop through the list and save names that start with `"A"`.

# %%
author_names = ["Austen", "Baldwin", "Alcott", "Dickens", "Atwood"]
a_authors = []

# Write your code below

# %% [markdown]
# ## Exercise 23: Case-insensitive string check
#
# Create a list called `city_names` with the values `["Atlanta", "boston", "Austin", "chicago", "ann arbor"]`. Save all city names that start with `"a"` or `"A"` in a list called `a_cities` using `.lower()` and `.startswith()`.

# %%
city_names = ["Atlanta", "boston", "Austin", "chicago", "ann arbor"]
a_cities = []

# Write your code below

# %% [markdown]
# ## Exercise 24: Write a function with if-else
#
# Write a function called `label_length()` that takes one parameter, `text`. If the text has more than 10 characters, return `"long text"`. Otherwise, return `"short text"`.

# %%
def label_length(text):
    # Write your code below

# %% [markdown]
# ## Exercise 25: Call the if-else function
#
# Call `label_length()` on the strings `"novel"` and `"digital archive"`.

# %%
# Write your code below

# %% [markdown]
# ## Exercise 26: Write a function with elif
#
# Write a function called `page_category()` that takes one parameter, `page_total`. Return `"short"` if the value is less than 150, `"medium"` if it is less than 400, and `"long"` otherwise.

# %%
def page_category(page_total):
    # Write your code below

# %% [markdown]
# ## Exercise 27: Loop and call a function
#
# Create a list called `page_totals` with the values `[95, 220, 510]`. Loop through the list using `page_category()`.

# %%
page_totals = [95, 220, 510]

# Write your code below

# %% [markdown]
# ## Exercise 28: Loop, conditional, and accumulator
#
# Create a list called `titles` with the values `["Orlando", "Old Man and the Sea", "Jane Eyre", "Oliver Twist", "Emma"]`. Create an empty list called `o_titles`. Loop through `titles` and save titles that start with `"O"`.

# %%
titles = ["Orlando", "Old Man and the Sea", "Jane Eyre", "Oliver Twist", "Emma"]
o_titles = []

# Write your code below
