# %% [markdown]
# # 1-3: Data Types and Structures Exercises
#
# This notebook gives you short practice exercises for Python data types and structures. Work through the cells in order. Each section has four exercises.
#
# The goal is to practice using:
#
# 1. floats
# 2. integers
# 3. strings
# 4. logicals
# 5. lists
# 6. dictionaries

# %% [markdown]
# ## Floats
#
# Floats are numbers with decimal values. Use them when you need more precision than whole numbers provide.

# %% [markdown]
# ### Exercise 1: Calculate an area with floats
#
# Create variables for the length and width of a table. Then calculate and print the area.

# %%
table_length = 6.5
table_width = 3.25

# Calculate the table area below
table_area = 

print(table_area)

# %% [markdown]
# ### Exercise 2: Calculate a rectangle's perimeter
#
# Use the variables below to calculate the perimeter of a poster.

# %%
poster_height = 11.5
poster_width = 8.5

# Formula: 2 * height + 2 * width
poster_perimeter = 

poster_perimeter

# %% [markdown]
# ### Exercise 3: Calculate a percentage
#
# Use the decimal below to calculate the percentage score.

# %%
correct_answers = 18.0
total_questions = 24.0

# Calculate the percentage 
# formula: divide the two variables then multiply by 100
score_percentage = 

score_percentage

# %% [markdown]
# ### Exercise 4: Convert a float to an integer
#
# Convert the float below into an integer and print its type.

# %%
float_example = 85.0
float_example = 

print(float_example)
print(type(float_example))

# %% [markdown]
# ## Integers
#
# Integers are whole numbers. They are useful for counting things.

# %% [markdown]
# ### Exercise 5: Add integer values
#
# Add the number of notebooks, folders, and pens.

# %%
notebooks = 4
folders = 3
pens = 12

# Calculate the total number of supplies
total_supplies = 

print(total_supplies)

# %% [markdown]
# ### Exercise 6: Subtract integer values
#
# Calculate how many seats are still open.

# %%
total_seats = 30
registered_students = 22

# Calculate the number of open seats
open_seats = 

print(open_seats)

# %% [markdown]
# ### Exercise 7: Multiply integer values
#
# Calculate the total number of pages printed.

# %%
pages_per_packet = 8
number_of_packets = 15

# Calculate total pages
total_pages = 

print(total_pages)

# %% [markdown]
# ### Exercise 8: Check an integer's type
#
# Use the `type()` function to check the type of `chapter_count`. If it isn't an integer, use `int` to convert it.

# %%
chapter_count = 14.0

# Check the data type of chapter_count
print(type(chapter_count))

# convert chapter_count to an integer
chapter_count =

# check the data type of chapter_count again
print(type(chapter_count))

# %% [markdown]
# ## Strings
#
# Strings are text values. In Python, strings are wrapped in quotation marks.

# %% [markdown]
# ### Exercise 9: Create and print a string
#
# Create a string variable with the title of a book, poem, film, or song. Then print it.

# %%
# Create a string variable below
work_title = 

print(work_title)

# %% [markdown]
# ### Exercise 10: Use string methods
#
# Use `.upper()` and `.lower()` on the string below.

# %%
course_name = "Digital Humanities"

print() # print course_name in uppercase
print() # print course_name in lowercase

# %% [markdown]
# ### Exercise 11: Count a word in a string
#
# Use `.count()` to count how many times the word `data` appears.

# %%
sentence = "data can describe data, but data also needs interpretation"

# Count the word data
data_count = 

print(data_count)

# %% [markdown]
# ### Exercise 12: Slice a string
#
# Use indexing or slicing to print only the word `archive` from the string below.

# %%
phrase = "digital archive project"

# Print only archive

# %% [markdown]
# ## Logicals
#
# Logical values are `True` or `False`. Comparison operators create logical outputs.

# %% [markdown]
# ### Exercise 13: Check equality
#
# Use `==` to check whether the two variables are equal.

# %%
first_count = 12
second_count = 12

# Check whether first_count and second_count are equal
print()

# %% [markdown]
# ### Exercise 14: Check inequality
#
# Use `!=` to check whether the two strings are different.

# %%
first_city = "Chicago"
second_city = "Detroit"

# Check whether first_city and second_city are different
print()

# %% [markdown]
# ### Exercise 15: Compare two numbers
#
# Use `>` to check whether `new_articles` is greater than `old_articles`.

# %%
new_articles = 45
old_articles = 38

# Check whether new_articles is greater than old_articles
print()

# %% [markdown]
# ### Exercise 16: Compare with less than or equal to
#
# Use `<=` to check whether the number of missing values is less than or equal to the limit.

# %%
missing_values = 5
limit = 10

# Check whether missing_values is less than or equal to limit
print()

# %% [markdown]
# ## Lists
#
# Lists store multiple values in one object. List items are ordered and can be accessed with indexes.

# %% [markdown]
# ### Exercise 17: Create a list
#
# Create a list of four archive names or library names. Then print the list.

# %%
# Create a list below
archives = 

print(archives)

# %% [markdown]
# ### Exercise 18: Index a list
#
# Print the first and third items from the list below.

# %%
media_formats = ["newspaper", "letter", "photograph", "map"]

print() # first item
print() # third item

# %% [markdown]
# ### Exercise 19: Slice a list
#
# Print the first three items from the list below.

# %%
methods = ["mapping", "text mining", "network analysis", "topic modeling", "data visualization"]

# Print the first three items

# %% [markdown]
# ### Exercise 20: Use a list method
#
# Use `.append()` to add another item to the list. Then print the updated list.

# %%
genres = ["poetry", "fiction", "drama"]

# Append another genre

print(genres)

# %% [markdown]
# ## Dictionaries
#
# Dictionaries store key-value pairs. They are useful when you want to label pieces of information.

# %% [markdown]
# ### Exercise 21: Create a dictionary
#
# Create a dictionary that stores information about one text. Include keys for `title`, `author`, and `year`.

# %%
# Create a dictionary below
text_record = {
    
}

print(text_record)

# %% [markdown]
# ### Exercise 22: Access a dictionary value
#
# Print the `city` value from the dictionary below.

# %%
library_record = {
    "name": "Newberry Library",
    "city": "Chicago",
    "state": "Illinois"
}

# Print the city value

# %% [markdown]
# ### Exercise 23: Overwrite a dictionary value
#
# Change the `status` value from `draft` to `complete`. Then print the dictionary.

# %%
project_record = {
    "project": "Newspaper Analysis",
    "status": "draft",
    "items": 250
}

# Change status to complete

print(project_record)

# %% [markdown]
# ### Exercise 24: Work with a nested dictionary
#
# Print the language value for Gabriela Mistral.

# %%
writers = {
    "Gabriela Mistral": {
        "name": "Gabriela Mistral",
        "year of birth": 1889,
        "language": "Spanish"
    },
    "Langston Hughes": {
        "name": "Langston Hughes",
        "year of birth": 1901,
        "language": "English"
    }
}

# Print Gabriela Mistral's language
