# %% [markdown]
# # 4-2: Network Analysis Exercises in Python
#
# In this exercise notebook, you will practice the network analysis workflow from the tutorial notebook, but with a different literary dataset: a character co-occurrence network for Shakespeare's _Romeo and Juliet_ from DraCor.
#
# The goal is to practice the same broad workflow:
#
# 1. Load nodes and edges
# 2. Inspect weighted edges and centrality columns
# 3. Build a network graph
# 4. Review network summary measures
# 5. Compare degree, weighted degree, and betweenness
# 6. Detect communities
# 7. Visualize the network
#
# This version includes answer cells marked with `# ANSWER (delete before sharing)` so the instructor can review the expected code. Before sharing with students, delete those answer cells.

# %% [markdown]
# ## Dataset Note
#
# The Les Mis tutorial starts with raw repeated edge rows and then calculates weighted edges and centrality measures.
#
# DraCor gives us a slightly different kind of dataset. Its Romeo and Juliet character table already includes useful network measurements, including:
#
# - `degree`
# - `weightedDegree`
# - `betweenness`
# - `closeness`
# - `eigenvector`
#
# Its edge table is also already weighted. The edge column `Weight` tells us how many dramatic segments contain both characters.
#
# So in this notebook, we'll also practice reading, sorting, comparing, graphing, and interpreting the network data that DraCor already provides.

# %% [markdown]
# ## Setup
#
# Install and import the libraries we need.

# %% [markdown]
# ### Exercise 0.1
#
# Install `networkx` using the Jupyter magic command `%pip install networkx`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 0.2
#
# Import the libraries with `import`: use `import pandas as pd`, `import matplotlib.pyplot as plt`, `import seaborn as sns`, and `import networkx as nx`.

# %%
# Write your code here

# %%
# ANSWER (delete before sharing)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# %% [markdown]
# ## Step 1: Load The Data From DraCor
#
# We will load two CSV files directly from DraCor:
#
# - a character table for _Romeo and Juliet_
# - a weighted network edge table for _Romeo and Juliet_
#
# The character table will become our `nodes` table. The network table will become our `edges` table.
#
# Unlike the tutorial notebook, we will let pandas infer data types. This keeps columns like `degree`, `weightedDegree`, `betweenness`, and `Weight` numeric, which makes sorting and plotting easier.

# %% [markdown]
# ### Exercise 1.1
#
# Create two URL variables, `nodes_url` and `edges_url`, with assignment (`=`). Then use `pd.read_csv()` to load them into DataFrames named `nodes` and `edges`.

# %%
# Write your code here

nodes_url = "https://dracor.org/api/v1/corpora/shake/plays/romeo-and-juliet/characters/csv"
edges_url = "https://dracor.org/api/v1/corpora/shake/plays/romeo-and-juliet/networkdata/csv"

nodes = 
edges =

# %% [markdown]
# ### Exercise 1.2
#
# Preview the first few rows of the character table with `.head()`.

# %%
# Write your code here

# %% [markdown]
# Each row in `nodes` is a character or character group. The `id` column gives a machine-readable identifier. The `name` column gives a readable name.
#
# Notice that this table already includes several network measures.

# %% [markdown]
# ### Exercise 1.3
#
# Preview the first few rows of the edge table with `.head()`.

# %%
# Write your code here

# %% [markdown]
# Each row in `edges` is a weighted co-occurrence between two character IDs. `Source` and `Target` are the two characters. `Type` tells us this is an undirected network. `Weight` tells us how often those two characters co-occur.

# %% [markdown]
# ### Exercise 1.4
#
# Print the number of character rows and weighted edge rows. Use `len()` and `print()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 1.5
#
# Inspect the data types in both tables. Use the `.dtypes` attribute and `print()`.

# %%
# Write your code here

# %% [markdown]
# ## Step 2: Review Weighted Edges And Precomputed Metrics
#
# In the tutorial, we created a `weighted_edges` table by grouping raw edges. Here, DraCor has already done that work for us. The `edges` table is already a weighted edge list.
#
# But we can still practice the same analytical habit: inspect the table, sort by important columns, and ask what the strongest relationships appear to be.

# %% [markdown]
# ### Exercise 2.1
#
# Sort `edges` by `Weight` from highest to lowest with `.sort_values()`, then preview the top 10 rows with `.head(10)`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 2.2
#
# Count the values in the `Type` column with `.value_counts()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 2.3
#
# Calculate the sum of the `Weight` column with `.sum()`. This gives the total number of weighted co-occurrence instances represented by the edge list.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 2.4
#
# Sort `nodes` by `degree` from highest to lowest with `.sort_values()`. Then use `.head()` to view the top ten rows by `degree`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 2.5
#
# Sort `nodes` by `weightedDegree` from highest to lowest with `.sort_values()`. Then use `.head()` the top ten rows by `weightedDegree`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 2.6
#
# Sort `nodes` by `betweenness` from highest to lowest with `.sort_values()`. Then use `.head()` to view the top ten rows by `betweenness`.

# %%
# Write your code here

# %% [markdown]
# ## Step 3: Build A Network With `networkx`
#
# Even though DraCor already gives us network measures, it is still useful to build a `networkx` graph. A graph object lets us inspect nodes and edges, detect communities, and draw network visualizations.
#
# Because this is a co-occurrence network, we will use `nx.Graph()`, which creates an undirected graph.

# %% [markdown]
# ### Exercise 3.1
#
# Create an empty undirected graph called `G` with `nx.Graph()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3.2
#
# Check the type of `G` with `type()`.

# %%
# Write your code here

# %% [markdown]
# Now add the character nodes. For each row in `nodes`, add one node to the graph. Attach the character's readable name as a node attribute.

# %% [markdown]
# ### Exercise 3.3
#
# Loop through `nodes` with `.iterrows()`. Inside the loop, add each character to `G` with `G.add_node()`, then use `print(G)`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3.4
#
# Loop through `edges` with `.iterrows()`. Inside the loop, use `int()` on `Weight` and add each weighted edge to `G` with `G.add_edge()`, then use `print(G)`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3.5
#
# Print the graph object again with `print(G)`. Does it have the right number of nodes and edges?

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3.6
#
# Inspect the graph's nodes. Use `G.nodes`, `print()`, `type()`, and `len()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3.7
#
# Inspect the graph's edges. Use `G.edges`, `print()`, `type()`, and `len()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3.8
#
# Print the graph's node and edge counts with `G.number_of_nodes()`, `G.number_of_edges()`, and `print()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3.9
#
# Inspect the node attributes for `Romeo_Rom`. Hint: try `G.nodes` followed by `[]`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3.10
#
# Inspect the edge attributes for the edge between `Romeo_Rom` and `Juliet_Rom` with bracket lookup: `G.edges["Romeo_Rom", "Juliet_Rom"]`.

# %%
# Write your code here

# %% [markdown]
# ## Step 4: Basic Network Summary
#
# Now calculate a few summary statistics for the whole network.

# %% [markdown]
# ### Exercise 4.1
#
# Calculate whether the graph is connected with `nx.is_connected()`, calculate density with `nx.density()`, and calculate average degree with `nodes["degree"].mean()`. Use `print()` to display all three values.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 4.2
#
# Find any characters with a degree of `0`. Hint: Boolean filtering with `nodes["degree"] == 0` and bracket column selection. What might a degree of `0` mean in this network model?

# %%
# Write your code here

# %% [markdown]
# ## Step 5: Degree Centrality
#
# DraCor has already calculated degree for us. Degree tells us how many other characters each character is directly connected to.

# %% [markdown]
# ### Exercise 5.1
#
# Create a DataFrame called `degree_df` by sorting `nodes` with `.sort_values("degree", ascending=False)`. Use `.head(10)` to preview columns.

# %%
# Write your code here

# %% [markdown]
# ## Step 6: Weighted Degree
#
# DraCor has also calculated weighted degree for us. Weighted degree uses the edge weights, so repeated or stronger co-occurrences count more.

# %% [markdown]
# ### Exercise 6.1
#
# Create a DataFrame called `weighted_degree_df` by sorting `nodes` with `.sort_values("weightedDegree", ascending=False)`. Use `.head(10)` to preview  columns.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 6.2
#
# Compare the top 10 by degree and the top 10 by weighted degree. Use `.head(10)`, column selection with `["name"]`, `.tolist()`, and `print()`.

# %%
# Write your code here

# %% [markdown]
# ## Step 7: Betweenness Centrality
#
# DraCor has already calculated betweenness centrality for us. Betweenness asks how often a character lies on shortest paths between other characters.

# %% [markdown]
# ### Exercise 7.1
#
# Create a DataFrame called `betweenness_df` by sorting `nodes` with `.sort_values("betweenness", ascending=False)`. Use `.head(10)` to preview columns.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 7.2
#
# Count how many characters have a betweenness centrality of `0`. Use a Boolean comparison, `nodes["betweenness"] == 0`, followed by `.sum()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 7.3
#
# Display the characters with betweenness centrality of `0`. Use Boolean filtering with `nodes["betweenness"] == 0` and bracket column selection.

# %%
# Write your code here

# %% [markdown]
# ## Step 8: Compare The Metrics
#
# The DraCor `nodes` table already has the metrics side by side, so we can create a focused analysis table from it.

# %% [markdown]
# ### Exercise 8.1
#
# Create a copy of `nodes` called `centrality_df` with `.copy()`. Then sort it with `.sort_values("degree", ascending=False)`, preview the top rows with `.head(10)`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 8.2
#
# Use bracket column selection to choose the centrality columns, then use `.describe()` to get summary statistics. Hint: remember: bracket column selections require two layers of brackets (a list within a list). See week 1 tutorials to jog your memory `[["column_1", "column_2"]]`.

# %%
# Write your code here

# %% [markdown]
# ## Step 9: Communities
#
# Community detection looks for groups of nodes that are more strongly connected to each other than to the rest of the network.
#
# DraCor does not give us a community column in this CSV, so this is one measurement we will calculate with `networkx`.

# %% [markdown]
# ### Exercise 9.1
#
# Detect communities with `nx.community.greedy_modularity_communities(G, weight="weight")`. Store the result in `communities`, then use `len()` and `print()` to display the number of communities detected.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 9.2
#
# Inspect the first community with list-style indexing: `communities[0]`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 9.3
#
# Create a dictionary called `community_lookup`. Use `{}` to start an empty dictionary, `enumerate(communities, start=1)`, nested `for` loops, and `print()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 9.4
#
# Add a `community` column to `centrality_df` by using `.map(community_lookup)` on the `id` column. Then preview the result with `.head(10)`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 9.5
#
# Count how many characters are in each community with `.value_counts()`, then sort the community numbers with `.sort_index()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 9.6
#
# Create a table called `top_by_community`. Use `.sort_values()`, `.groupby("community")`, `.head(3)`, and bracket column selection to show `community`, `name`, `degree`, `weightedDegree`, and `betweenness`.

# %%
# Write your code here

# %% [markdown]
# ## Step 10: Visualize Top Characters
#
# First, create a simple bar chart of the top 10 characters by degree.

# %% [markdown]
# ### Exercise 10.1
#
# Create a DataFrame called `top_degree` with `.sort_values("degree", ascending=False)` and `.head(10)`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 10.2
#
# Use `seaborn` and `matplotlib` to make a horizontal bar chart. Use `sns.set_theme()`, `.copy()`, `.astype(str)`, `plt.figure()`, `sns.barplot()`, `plt.title()`, `plt.xlabel()`, `plt.ylabel()`, `plt.legend()`, and `plt.show()`.

# %%
# Write your code here

# %% [markdown]
# ## Step 11: Draw A Manageable Subgraph
#
# Now draw a smaller network containing the top 25 characters by degree.

# %% [markdown]
# ### Exercise 11.1
#
# Create a list of the top 25 character IDs by degree with `.sort_values()`, `.head(25)`, column selection, and `.tolist()`. Then use `G.subgraph()`, `.copy()`, and `print()` to make and inspect `top_25_graph`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 11.2
#
# Create a spring layout for the subgraph with `nx.spring_layout()`. Use the arguments `seed=42` and `weight="weight"`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 11.3
#
# Create `node_sizes` and `node_colors` lists for the subgraph.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 11.4
#
# Create an `edge_widths` list for the subgraph. Use an empty list, a `for` loop over `top_25_graph.edges()`, edge attribute lookup with `top_25_graph.edges[source, target]["weight"]`, and `.append()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 11.5
#
# Draw the top 25 character network with `matplotlib` and `networkx`. Use `plt.figure()`, `nx.draw_networkx_edges()`, `nx.draw_networkx_nodes()`, `nx.get_node_attributes()`, `nx.draw_networkx_labels()`, `plt.title()`, `plt.axis("off")`, and `plt.show()`.

# %%
# Write your code here

# %% [markdown]
# ## Step 12: Draw The Full Network
#
# Finally, draw the full Romeo and Juliet character co-occurrence network.

# %% [markdown]
# ### Exercise 12.1
#
# Create a spring layout for the full graph with `nx.spring_layout()`. Use the arguments `seed=42`, `weight="weight"`, and `k=0.4`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 12.2
#
# Create full-network `node_sizes` and `node_colors` lists. Use empty lists, a `for` loop over `G.nodes()`, `.loc[]`, `.append()`, and `print()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 12.3
#
# Create full-network edge widths. Use an empty list, a `for` loop over `G.edges()`, edge attribute lookup with `G.edges[source, target]["weight"]`, `.append()`, and `print()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 12.4
#
# Create a label dictionary for only the top 15 characters by degree. Use `.sort_values()`, `.head(15)`, column selection, an empty dictionary, a `for` loop, node attribute lookup with `G.nodes[character_id]["name"]`, and `print()`.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 12.5
#
# Draw the full graph with `matplotlib` and `networkx`. Use `plt.figure()`, `nx.draw_networkx_edges()`, `nx.draw_networkx_nodes()`, `nx.draw_networkx_labels()`, `plt.title()`, `plt.axis("off")`, and `plt.show()`.

# %%
# Write your code here
