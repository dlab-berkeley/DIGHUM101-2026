# %% [markdown]
# # 5-1: Topic Modeling Exercises
#
# In this exercise notebook, you will practice the full topic-modeling workflow from `week_5/5-2_topic_modeling.ipynb`, but with a different corpus.
#
# You'll work with the text files in `../data/human-rights-exercise`. These are eleven United Nations Human Rights Council Universal Periodic Review reports from 2020-2026. The documents come from different countries. The code from the tutorial should work on these documents, but you'll need to change file paths, stop words, and other parts of the process to analyze these documents' topics appropriately.
#
# All of this data comes from the [United Nations Digital Library](https://digitallibrary.un.org/). Source record links for each document are listed in `../data/human-rights-exercise/metadata.csv`. You can also search the UN Digital Library for [Report of the Working Group on the Universal Periodic Review](https://digitallibrary.un.org/search?ln=en&p=%22Report%20of%20the%20Working%20Group%20on%20the%20Universal%20Periodic%20Review%22&f=title&action_search=Search).

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Exercise 1: Install and import the libraries
#
# Use the setup section from the tutorial as your model.
#
# Install `pyLDAvis` if needed, then import the same libraries and modules used in the tutorial:
#
# - `Counter`
# - `glob`
# - `os`
# - `re`
# - `gensim`
# - `pandas`
# - `matplotlib.pyplot`
# - `seaborn`
# - `corpora` and `LdaModel` from `gensim`
# - `LatentDirichletAllocation`
# - `CountVectorizer` and `ENGLISH_STOP_WORDS`
# - `pyLDAvis`

# %%
# Import the tutorial libraries below

# %% [markdown]
# ## Step 1: Load The Text Files

# %% [markdown]
# ### Exercise 2: Create the file paths
#
# Set `data_folder` to `../data/human-rights-exercise`.
#
# Then use `glob()` and `os.path.join()` to create a sorted list of `.txt` file paths called `file_paths`. Print the number of files found and preview the first three paths.

# %%
data_folder = "../data/human-rights-exercise"

# Create file_paths below

# %% [markdown]
# ### Exercise 3: Load the reports into a dataframe
#
# Use the tutorial loop to read each text file into a list of dictionaries called `records`.
#
# Then turn `records` into a dataframe called `human_rights` and create a `word_count` column.
#
# Keep the same columns as the tutorial:
#
# - `file`
# - `document`
# - `text`
# - `word_count`

# %%
# Your code here

# %% [markdown]
# ### Exercise 4: Assess document length and preview a report
#
# Display the dataframe and look at the `word_count` column.
#
# Are the documents reasonably comparable in length? Then print the first 1000 characters of the first report.

# %%
# Your code here

# %% [markdown]
# ## Step 2: Preprocess The Text

# %% [markdown]
# ### Exercise 5: Create a raw word-frequency table
#
# Before removing stop words, use the tutorial's raw frequency loop to create:
#
# - `raw_tokens`
# - `raw_word_counts`
# - `raw_top_words`
#
# Use the regex pattern from the tutorial:
#
# ```python
# re.findall(r"[a-z]{3,}", text)
# ```
#
# This keeps alphabetic tokens with at least three letters and ignores numeric characters.

# %%
# Your code here

# %% [markdown]
# ### Exercise 6: Choose corpus-specific stop words
#
# Use `raw_top_words` to decide which common words are mostly boilerplate or institutional language.
#
# Create a set called `UN_stopwords`. You may start with the tutorial's stop-word list, but adjust it for this new corpus. For example, remove a word if it seems meaningful for your interpretation, or add a word if it appears to be repeated UN report language.
#
# Then create `UN_stopword_counts` to check how often those words appeared in the raw corpus.

# %%
UN_stopwords = {
    # Add corpus-specific stop words here
}

# Create UN_stopword_counts below

# %% [markdown]
# ### Exercise 7: Write and apply the preprocessing function
#
# Combine `ENGLISH_STOP_WORDS` with your `UN_stopwords` set.
#
# Then write a `preprocess_text()` function that follows the tutorial:
#
# 1. Lowercase the text
# 2. Use `re.findall(r"[a-z]{3,}", text)` to tokenize
# 3. Create an empty list called `cleaned_tokens`
# 4. Loop through `tokens`
# 5. Append only tokens that are not in `stop_words`
# 6. Return `cleaned_tokens`
#
# Apply the function to `human_rights["text"]` and save the result in a new column called `tokens`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 8: Create the `text_processed` column
#
# `gensim` can work with the token lists in `human_rights["tokens"]`, but `scikit-learn`'s `CountVectorizer` expects each document to be a string.
#
# Write a `join_tokens()` function, then use `.apply()` to create a `text_processed` column.

# %%
# Your code here

# %% [markdown]
# ### Exercise 9: Inspect cleaned tokens
#
# Print the first few tokens from the first document. Do they look reasonable after preprocessing?

# %%
# Your code here

# %% [markdown]
# ### Exercise 10: Create a post-preprocessing frequency table
#
# Use the tutorial's nested-loop pattern to combine all document tokens into a corpus-wide list called `all_tokens`.
#
# Then create `word_counts` and a dataframe called `top_words` showing the 20 most common words after preprocessing.

# %%
# Your code here

# %% [markdown]
# ### Exercise 11: Plot the most common words after preprocessing
#
# Create a horizontal bar chart of `top_words`.
#
# If the most common words still look too generic, revise your `UN_stopwords`, rerun the preprocessing cells, and check the table again.

# %%
# Your code here

# %% [markdown]
# ## Step 3: Create A Document-Term Matrix

# %% [markdown]
# ### Exercise 12: Create the document-term matrix
#
# Use `CountVectorizer` with the same settings as the tutorial:
#
# - `max_df=0.9`
# - `min_df=2`
# - `max_features=500`
# - `ngram_range=(1, 2)`
#
# Then use `.fit_transform()` on `human_rights["text_processed"]` to create `dtm`.
#
# Print the type and shape of `dtm`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 13: Inspect the learned vocabulary
#
# Use `.get_feature_names_out()` to create `vocab`, then preview the first 25 terms.

# %%
# Your code here

# %% [markdown]
# ### Exercise 14: Convert the DTM preview to a dataframe
#
# Create `dtm_df` from `dtm.toarray()`, using `vocab` as the columns and `human_rights["file"]` as the index.
#
# Display the first few rows and columns.

# %%
# Your code here

# %% [markdown]
# ## Step 4: Fit The LDA Topic Model

# %% [markdown]
# ### Exercise 15: Fit a `scikit-learn` LDA model
#
# Set `n_topics = 5`, create a `LatentDirichletAllocation` model with the tutorial settings, and fit it to `dtm`.
#
# Keep `random_state=42` so your output is repeatable.

# %%
# Your code here

# %% [markdown]
# ### Exercise 16: Inspect `lda.components_`
#
# Print the type, shape, and contents of `lda.components_`.
#
# What do the rows and columns represent?

# %%
# Your code here

# %% [markdown]
# ### Exercise 17: Create a topic-word table
#
# Copy or adapt the tutorial's `get_top_words()` helper function.
#
# Use it to create a dataframe called `topic_words` with the top 12 words for each topic.

# %%
# Your code here

# %% [markdown]
# ### Exercise 18: Interpret the topic-word lists
#
# Look at `topic_words` and give each topic a tentative label.
#
# Remember: a topic is a statistical cluster of words, not automatically a humanistic theme. Your labels should stay provisional.

# %%
# Use this cell for notes, topic labels, or quick print statements

# %% [markdown]
# ### Exercise 19: Inspect one topic more closely
#
# Choose one topic number and create `topic_weights`, a dataframe showing every vocabulary word and its topic-word weight for that topic.
#
# Sort the table from highest to lowest weight and display the top 15 rows.

# %%
# Your code here

# %% [markdown]
# ### Exercise 20: Plot the top words for one topic
#
# Use the tutorial code to create a bar chart of the top 12 words for one topic.
#
# Try changing `topic_to_plot` and rerunning the cell.

# %%
# Your code here

# %% [markdown]
# ## Step 5: Inspect Document-Topic Mixtures

# %% [markdown]
# ### Exercise 21: Create a document-topic dataframe
#
# Use `lda.transform(dtm)` to create `doc_topic`.
#
# Then create `topic_columns`, `doc_topic_df`, and `top_topic` exactly as in the tutorial.

# %%
# Your code here

# %% [markdown]
# ### Exercise 22: Count dominant topics
#
# Count how many documents have each topic as their highest-weighted topic.

# %%
# Your code here

# %% [markdown]
# ### Exercise 23: Create a topic-mixture heatmap
#
# Use `sns.heatmap()` to visualize the topic weights for each document.
#
# Which reports have a dominant topic? Which reports look more mixed?

# %%
# Your code here

# %% [markdown]
# ## Step 6: Visualize The Model With `pyLDAvis`

# %% [markdown]
# ### Exercise 24: Prepare and display the `pyLDAvis` panel
#
# Use the tutorial code to create:
#
# - `topic_term_dists`
# - `doc_topic_dists`
# - `doc_lengths`
# - `term_frequency`
# - `panel`
#
# Then display the panel with `pyLDAvis.display(panel)`.
#
# If `pyLDAvis` does not display well in your editor, you can still complete the rest of the exercise using the tables and plots above.

# %%
# Your code here

# %% [markdown]
# ### Exercise 25: Read the visualization carefully
#
# Use the `pyLDAvis` panel to answer these questions:
#
# - Which topics overlap?
# - Which terms are common but not very distinctive?
# - Which terms become more important when lambda is lower?
# - Do the visual patterns match your document-topic heatmap?

# %%
# Use this cell for notes or quick checks

# %% [markdown]
# ## Step 7: Run A Comparable Model With `gensim`

# %% [markdown]
# ### Exercise 26: Create the `gensim` dictionary and corpus
#
# Use the `tokens` column to create:
#
# - `dictionary`
# - `corpus`
#
# Filter the dictionary with the tutorial settings:
#
# ```python
# dictionary.filter_extremes(no_below=2, no_above=0.9, keep_n=500)
# ```
#
# Then print the number of dictionary terms, the number of documents, and a preview of the first bag-of-words document.

# %%
# Your code here

# %% [markdown]
# ### Exercise 27: Fit the `gensim` LDA model
#
# Use `LdaModel()` with the same settings as the tutorial:
#
# - `num_topics=n_topics`
# - `random_state=42`
# - `passes=30`
# - `iterations=100`
#
# Then print the top 12 words for each topic.

# %%
# Your code here

# %% [markdown]
# ### Exercise 28: Create the `gensim` document-topic dataframe
#
# Use `lda_gensim.get_document_topics()` to create `gensim_doc_topic_df`.
#
# Include a `top_topic` column, just as you did with the `scikit-learn` model.

# %%
# Your code here

# %% [markdown]
# ### Exercise 29: Plot the `gensim` topic-mixture heatmap
#
# Create a heatmap from `gensim_doc_topic_df`.
#
# How does it compare to the `scikit-learn` heatmap?

# %%
# Your code here

# %% [markdown]
# ## Reflection

# %% [markdown]
# ### Exercise 30: Write a short interpretation
#
# In a few sentences, reflect on your model:
#
# - Which preprocessing choices mattered most?
# - Which topics seem interpretable?
# - Which topics seem noisy or hard to label?
# - Which reports would you want to read more closely after seeing the model output?
# - What claims would be too strong to make from this small corpus?

# %%
# Write notes here, or use a markdown cell below
