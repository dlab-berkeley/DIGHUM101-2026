# %% [markdown]
# # 2-2: Pandas Exercises
#
# This notebook gives you short practice exercises for the pandas concepts in `2-2_pandas_overview.ipynb`.
#
# You will work with `music_reviews_clean.csv`, a dataset of album reviews. Be sure to work through the cells in order. Later exercises use columns you rename earlier in the notebook.

# %% [markdown]
# ## Setup and File Paths

# %% [markdown]
# ### Exercise 1: Import pandas
#
# Import pandas using the standard abbreviation `pd`.

# %%
# Import pandas below

# %% [markdown]
# ### Exercise 2: Check your working directory
#
# Import `os`, then use `os.getcwd()` to check your current working directory.

# %%
# Check your current working directory below

# %% [markdown]
# ### Exercise 3: Load the music reviews CSV
#
# Use `pd.read_csv()` to load `music_reviews_clean.csv` into a dataframe called `reviews`.
#
# If the starter path does not work on your computer, edit `csv_path` so that it points to your copy of the CSV file.

# %%
csv_path = "../data/music_reviews_clean.csv"

# Load the CSV into a dataframe called reviews


# Show the first few rows

# %% [markdown]
# ## First Look at the Data

# %% [markdown]
# ### Exercise 4: Use `.head()`
#
# Use `.head()` to view the first five rows of `reviews`.

# %%
# View the first five rows below

# %% [markdown]
# ### Exercise 5: View more rows with `.head()`
#
# Use `.head(20)` to view the first twenty rows of `reviews`.

# %%
# View the first twenty rows below

# %% [markdown]
# ### Exercise 6: Check Length of the Dataframe
#
# Use `len()` to check the number of rows in the dataframe.

# %%
# use len() on the dataframe below

# %% [markdown]
# ### Exercise 7: Count values in `genre`
#
# Use `.value_counts()` to count how many reviews appear in each `genre`.

# %%
# Count the values in the genre column below

# %% [markdown]
# ### Exercise 8: Count values in `critic`
#
# Use `.value_counts()` to see which critics appear most often.

# %%
# Count the values in the critic column below

# %% [markdown]
# ## Dataframe Attributes

# %% [markdown]
# ### Exercise 9: Check the shape
#
# Use `.shape` to see how many rows and columns are in `reviews`.

# %%
# Check the dataframe shape below

# %% [markdown]
# ### Exercise 10: Check the data types
#
# Use `.dtypes` to see the data type of each column.

# %%
# Check the dataframe data types below

# %% [markdown]
# ### Exercise 11: Check the column names
#
# Use `.columns` to view the column names in `reviews`.

# %%
# View the column names below

# %% [markdown]
# ## Working with Columns

# %% [markdown]
# ### Exercise 12: Select one column
#
# Select the `album` column and use `.head()` to view its first five values.

# %%
# Select the album column and view its first five values below

# %% [markdown]
# ### Exercise 13: Describe one column
#
# Use `.describe()` on the `score` column.

# %%
# Describe the score column below

# %% [markdown]
# ### Exercise 14: Select multiple columns
#
# Select the `album`, `artist`, and `score` columns. Use `.head()` to view the first five rows of this smaller dataframe.

# %%
# Select album, artist, and score below

# %% [markdown]
# ### Exercise 15: Use `help()` on `.rename()`
#
# Use `help()` to look up the pandas `.rename()` method.

# %%
# Use help() on reviews.rename below

# %% [markdown]
# ### Exercise 16: Rename the columns
#
# Use `.rename()` to rename the columns. Use `inplace = True` so the dataframe changes.
#
# Rename them like this:
#
# - `album` becomes `Album`
# - `artist` becomes `Artist`
# - `genre` becomes `Genre`
# - `release_date` becomes `Release Date`
# - `critic` becomes `Critic`
# - `score` becomes `Score`
# - `body` becomes `Review Text`

# %%
# Rename the columns below


# View the updated dataframe

# %% [markdown]
# ### Exercise 17: Add an empty column
#
# Add a new column called `Notes` and fill it with empty strings.

# %%
# Add an empty Notes column below

# View the first few rows

# %% [markdown]
# ### Exercise 18: Drop a column
#
# Use `.drop()` to remove the `Notes` column. Save the result back into `reviews`.

# %%
# Drop the Notes column below

# View the first few rows

# %% [markdown]
# ### Exercise 19: Create a `Year` column
#
# Use the `Release Date` column to create a new column called `Year`.
#
# Hint: the overview notebook used `.str.split("-").str[0]`.

# %%
# Create a Year column from Release Date below
reviews["Year"] = 

# View the first few rows

# %% [markdown]
# ### Exercise 20: Create `Month` and `Day` columns
#
# Use the `Release Date` column to create two new columns: `Month` and `Day`.

# %%
# Create Month and Day columns from Release Date below
reviews["Month"] = 
reviews["Day"] = 

# View the first few rows

# %% [markdown]
# ## Slicing Rows

# %% [markdown]
# ### Exercise 21: Slice consecutive rows
#
# Use row slicing to view rows 50 through 59 of `reviews`.

# %%
# Slice rows 50 through 59 below

# %% [markdown]
# ### Exercise 22: Use `.iloc` for one row
#
# Use `.iloc` to view the row at integer position `10`.

# %%
# Use .iloc to view row 10 below

# %% [markdown]
# ### Exercise 23: Use `.iloc` for non-consecutive rows
#
# Use `.iloc` to view rows at positions `3`, `11`, and `28`.

# %%
# Use .iloc to view rows 3, 11, and 28 below

# %% [markdown]
# ### Exercise 24: Use `.loc` for one cell
#
# Use `.loc` to select the value in row label `10` and the `Album` column.

# %%
# Use .loc to select row 10 and the Album column below

# %% [markdown]
# ### Exercise 25: Use `.iloc` for one cell
#
# Use `.iloc` to select the same cell from Exercise 24. Remember that `Album` is the first column after renaming.

# %%
# Use .iloc to select row 10 and column 0 below

# %% [markdown]
# ## Conditional Subsetting

# %% [markdown]
# ### Exercise 26: Make a Rap reviews dataframe
#
# Use `.loc` to create a new dataframe called `rap_reviews` that contains only rows where `Genre` is equal to `"Rap"`.

# %%
# Create a dataframe of Rap reviews below
rap_reviews = 

# View rap_reviews

# %% [markdown]
# ### Exercise 27: Make a high-score dataframe
#
# Use `.loc` to create a new dataframe called `high_scores` that contains only rows where `Score` is greater than or equal to `90`.

# %%
# Create a dataframe of reviews with scores greater than or equal to 90 below
high_scores = 

# View high_scores

# %% [markdown]
# ### Exercise 28: Use `&` for two conditions
#
# Create a dataframe called `rap_high_scores` that includes only reviews where:
#
# - `Genre` is equal to `"Rap"`
# - `Score` is greater than or equal to `90`

# %%
# Create a dataframe of high-scoring Rap reviews below
rap_high_scores = 

# View rap_high_scores

# %% [markdown]
# ### Exercise 29: Use `|` for either/or conditions
#
# Create a dataframe called `rock_reviews` that includes reviews where `Genre` is either `"Rock"` or `"Pop/Rock"`.

# %%
# Create a dataframe of Rock or Pop/Rock reviews below
rock_reviews = 

# Print the shape, then view rock_reviews

# %% [markdown]
# ## Sorting, Grouping, and Plotting

# %% [markdown]
# ### Exercise 30: Sort by release date
#
# Use `.sort_values()` to sort `reviews` by `Release Date` in ascending order.

# %%
# Sort reviews by Release Date below

# %% [markdown]
# ### Exercise 31: Sort a subset
#
# Create a dataframe of only `"Indie"` reviews, then sort it by `Score` from highest to lowest.

# %%
# Create an Indie subset and sort it by Score in descending order below

# %% [markdown]
# ### Exercise 32: Count reviews by Year
#
# Import `matplotlib.pyplot` as `plt`. Then create a variable called `reviews_per_year` that counts how many reviews appear in each `Year`.
#
# Hint: use `.value_counts().sort_index()`.

# %%
# Import matplotlib.pyplot below

# Count reviews by Year below


# View reviews_per_year

# %% [markdown]
# ### Exercise 33: Plot reviews by year
#
# Use `plt.plot()` to create a simple line plot of `reviews_per_year`. Add a title, x-axis label, y-axis label, and `plt.show()`.

# %%
# Create a line plot below

# Add a title

# Add x and y labels

# Display the plot
