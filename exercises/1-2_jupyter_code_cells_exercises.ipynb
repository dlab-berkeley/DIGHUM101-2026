# %% [markdown]
# # Exercies 1-2: Code Cells in Jupyter Notebooks
#
# ## Overview
#
# This notebook gives you practice writing and running Python code cells in Jupyter. It is designed to follow `1-2_jupyter_markdown_python.ipynb`.
#
# ## Learning Objectives
#
# By the end of this notebook, you should be able to:
#
# - Run code cells in Jupyter
# - Use `print()` to display output
# - Use Python as a calculator
# - Assign values to variables
# - Use variables in calculations
# - Read simple error messages
# - Fix common beginner mistakes
# - Understand why the order of code cells matters

# %% [markdown]
# ## Directions
#
# For each exercise:
#
# 1. Read the directions in the Markdown cell.
# 2. Write or edit code in the code cell below it.
# 3. Run the code cell with the Jupyter buttons or with __Shift + Return__ on Mac or __Shift + Enter__ on PC.
# 4. Check the output.
# 5. If you get an error, read the final line of the error message and try again.

# %% [markdown]
# ## Exercise 1: Run Your First Code Cell
#
# Run the code cell below. Then look at the execution count next to the cell. It should show that the cell has been run.

# %%
print("Hello, world!")

# %% [markdown]
# ## Exercise 2: Write Your Own `print()` Statement
#
# In the code cell below, write a `print()` statement that prints your name or a short greeting.
#
# Example:
#
# ```python
# print("Hello, my name is Matthew.")
# ```

# %%
# Write your print statement below

# %% [markdown]
# ## Exercise 3: Print Multiple Lines
#
# Write three separate `print()` statements. Each one should print a different line of text.
#
# You might print:
#
# - your name
# - your major or field
# - one thing you hope to learn in this class

# %%
# Write three print statements below

# %% [markdown]
# ## Exercise 4: Use Python as a Calculator
#
# Python can do math. Run the examples below, then change at least one number in each line and run the cell again.

# %%
print(10 + 4)
print(10 - 4)
print(10 * 4)
print(10 / 4)

# %% [markdown]
# ## Exercise 5: Order of Operations
#
# Python follows the usual order of operations. Parentheses are evaluated first.
#
# Before running the cell, try to guess the output of each line.

# %%
print(10 + 4 * 2)
print((10 + 4) * 2)

# %% [markdown]
# ## Exercise 6: Create a Variable
#
# Create a variable called `lucky_number` and assign it your lucky number. Then print it.

# %%
# Replace the blank with your lucky number
lucky_number = 
lucky_number

# %% [markdown]
# ## Exercise 7: Use a Variable in a Calculation
#
# The variable `books_read` has already been created for you. Create a second variable called `books_remaining`.
#
# Then create a third variable called `total_books` that adds the two variables together.

# %%
books_read = 4

# Create books_remaining below


# Add books_read and books_remaining below
total_books = 

total_books

# %% [markdown]
# ## Exercise 8: Calculating with Variables
#
# Let's use variables to calculate a simple population increase over time.
#
# The code below creates four variables:
#
# - `start_year`
# - `end_year`
# - `annual_increase`
# - `gdp_per_population`
#
# Complete the code by calculating:
#
# 1. the number of years between `start_year` and `end_year`
# 2. the total population increase
# 3. the estimated GDP increase from that population growth

# %%
start_year = 2026
end_year = 2030
annual_increase = 500
gdp_per_person = 65000

# Calculate the number of years
years = 

# Calculate the total population increase
population_increase = 

# Calculate the GDP increase
gdp_increase = 

gdp_increase

# %% [markdown]
# ## Exercise 9: Change the Variables
#
# Copy your working code from Exercise 8 into the cell below.
#
# Then change the values of the variables so that:
#
# - `start_year` is `2030`
# - `end_year` is `2040`
# - `annual_increase` is `750`
# - `gdp_per_person` is `70000`
#
# How does the final result change?

# %%
# Copy and revise your Exercise 8 code here

# %% [markdown]
# ## Exercise 10: Comments
#
# Comments begin with the `#` symbol. Python ignores comments, but human readers use them to understand the code.
#
# Add one comment above each line of code below explaining what the line does.

# %%
start_year = 2026
end_year = 2030
years = end_year - start_year
years

# %% [markdown]
# ## Exercise 11: Code Runs in Order
#
# The cell below has code in the wrong order. It will produce an error.
#
# Run the cell once. Then fix the order of the lines so that it works.

# %%
# This code is intentionally broken

final_population_broken = starting_population_broken + total_increase_broken

start_year_broken = 2026
end_year_broken = 2030
annual_increase_broken = 500
starting_population_broken = 5000

years_broken = end_year_broken - start_year_broken
total_increase_broken = years_broken * annual_increase_broken

final_population_broken

# %% [markdown]
# ## Exercise 12: Variable Names
#
# The code below contains invalid or inconsistent variable names.
#
# Fix the code so that it runs correctly.
#
# Things to remember:
#
# - Variable names cannot contain spaces
# - Variable names cannot contain periods
# - Variable names cannot start with a number
# - Variable names are case-sensitive

# %%
1st_paycheck = 2000
Second_paycheck = 2500

total_earnings = 1st_paycheck + second_paycheck
total_earnings

# %% [markdown]
# ## Exercise 13: Read the Error Message
#
# The code below contains a common syntax error.
#
# Run the cell once. Read the error message. Then fix the code.

# %%
print "Something went wrong"

# %% [markdown]
# ## Exercise 14: Variables Stay in Memory
#
# Do you remember your lucky number? Before running the following code, your previous lucky_number needs to be defined.
#
# Have you restarted the Kernel or exited VS Code then returned to these exercises? If yes, you'll need to redefine `lucky_number`. If not, this code should work. What will your luckier number be?

# %%
luckier_number = lucky_number + 1
# what will luckier_number be?
luckier_number

# %% [markdown]
# ## Exercise 15: Restarting the Kernel
#
# Try this:
#
# 1) Go to `Kernel -> Restart Kernel`.
# 2) Run the following cell.
#
# What happens? Write one sentence below explaining the result.

# %%
luckier_number
