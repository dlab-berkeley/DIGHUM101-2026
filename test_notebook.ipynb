# %% [markdown]
# # WELCOME
#
# This class is gonna be amazing OMG. Can't wait.
#
# Testing testing, this is the test notebook.

# %%
print('testing testing')
print('this is the test notebook')
# Out:
# testing testing
# this is the test notebook

# %%
4 / 2
# Out:
# 2.0

# %%
4+2
# Out:
# 6

# %%
4*2
# Out:
# 8

# %%
4-2
# Out:
# 2

# %%
a = 4+2
a
# Out:
# 6

# %%
print(a)
# Out:
# 6

# %%
boop boop this will result in an error
# Out:
#   Cell In[8], line 1
#     boop boop this will result in an error
#          ^
# SyntaxError: invalid syntax
